# %%
import cv2 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
eyes_cascade=cv2.CascadeClassifier("Train/third-party/frontalEyes35x16.xml")

# %%
nose_cascade=cv2.CascadeClassifier("Train/third-party/Nose18x15.xml")

# %%
img = cv2.imread("Train/Jamie_Before.jpg")

# %%
img.shape
# Out:
# (1024, 733, 3)

# %%
# cv2.imshow("Filter",img)

# cv2.waitKey(0)

# cv2.destroyAllWindows()
#cant  run this in juyter

# %%
plt.imshow(img[:,:,[2,1,0]])

# %%
img.shape
# Out:
# (1024, 733, 3)

# %%
        face= cv2.imread("Train/Jamie_Before.jpg",)
        specs=cv2.imread("Train/glasses.png",)
        mustache=cv2.imread("Train/mustache.png")

        xe,ye,we,he = eyes_cascade.detectMultiScale(img, 1.5, 5)[0]
        eyes = face[ye:ye+he,xe:xe+we]
        plt.imshow(eyes)

        nose = nose_cascade.detectMultiScale(img, 1.9, 5)

#         for eye in eyes:
#             x, y, w, h = eye

#             cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0, 0), 2)
        
#         for n in nose:
#             x, y, w, h = n

#             cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0, 0), 2)
          
          
           
            
            
        cv2.imshow("Filtered", img)
        key = cv2.waitKey(1) #1ms wait by waitkey function
        if key == ord("q"):
            break
cv2.destroyAllWindows()

# %%
specs = cv2.resize(specs,(150,69))

plt.imshow(specs)

for i in range(we):
    for j in range(he):
        if specs[j,i,3]>0:
              eyes[j,i,:] = specs[j,i,:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-95918ac480ca> in <module>
#       3 plt.imshow(specs)
#       4
# ----> 5 for i in range(we):
#       6     for j in range(he):
#       7         if specs[j,i,3]>0:
#
# NameError: name 'we' is not defined

# %%
df=pd.DataFrame(np.reshape(img,(-1,3)),columns=['Channel 1','Channel 2','Channel 3'])

# %%
df.to_csv('Filtered.csv',index=False)

# %%
img.shape
