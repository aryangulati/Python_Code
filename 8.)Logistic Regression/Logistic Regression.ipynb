# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=500, n_features=2, centers=2, random_state=2)

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
plt.scatter(X[:, 0], X[:, 1],c = y)
plt.show()

# %%
y.shape #it gives problem (500,) <== vector
# Out:
# (500, 1)

# %%
y = y.reshape(-1, 1)

# %%
y.shape
# Out:
# (500, 1)

# %%
ones = np.ones((500,1))
X_ = np.hstack((ones, X)) #this is forappending X0 in col

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( X_, y, test_size=0.33, random_state=42)

# %%
X_train.shape
# Out:
# (335, 3)

# %%
X_test.shape
# Out:
# (165, 3)

# %%
y_train.shape
# Out:
# (335, 1)

# %%
y_test.shape
# Out:
# (165, 1)

# %% [markdown]
# # Logistic Regression

# %%
def sigmoid(x):
    return 1.0/ (1.0 + np.exp(-1*x)) #this is vectorization
#we arejust passing x as scalar / vector(array)

# %%
#we can too check for sigmoid func
sigmoid(8)
# Out:
# 0.9996646498695336

# %%
sigmoid(np.array([5,8,-100,6,1,-4]))
# Out:
# array([9.93307149e-01, 9.99664650e-01, 3.72007598e-44, 9.97527377e-01,
#        7.31058579e-01, 1.79862100e-02])

# %%
def hypothesis(X, theta):
    """
    X - np array (m,n+1)
    theta - np arrary (n+1, 1)
    """
    return sigmoid( np.dot(X,theta) )

# %%
def error(X, y, theta):
    """
    params:
        X - np array (m,n+1)
        y - np array (m, 1)
        theta - np arrary (n+1, 1)
    
    return :
        scalar value = loss value
    """

    
    y_hat = hypothesis(X, theta) # (m,1)
    err = (y * np.log(y_hat) + ((1- y) * np.log(1-y_hat)) ).mean()
    #sum/m =mean()
    
    return -err #this is bcz we have to minimize

# %%
def gradient(X, y, theta):
    """
    X - np array (m,n+1)
    y - np array (m, 1)
    theta - np arrary (n+1, 1)
    """
    

    
    y_hat = hypothesis(X, theta)
    grad = np.dot( X.T , (y_hat - y) )
   
    return grad/X.shape[0]

# %%
def gradient_descent(X, y, lr =0.5, max_itr = 500):
    theta = np.zeros((X.shape[1],1))
    
    error_list = []
    
    for i in range(max_itr):
        
        err = error(X, y, theta)
        error_list.append(err)
        
        grad = gradient(X, y, theta)
        
        # Updation Rule
        theta = theta - lr*grad
        
    return (theta, error_list)

# %%
X.shape
#we have to append x0 column for X0theta0
# Out:
# (500, 2)

# %%
opt_theta, error_list = gradient_descent(X_train, y_train)

# %%
error_list
# Out:
# [0.6931471805599453,
#  0.7705146098052269,
#  0.5048781158962592,
#  0.3390403003233697,
#  0.2597808399028101,
#  0.2357231564510378,
#  0.2215002897535513,
#  0.20943856561633342,
#  0.19902495296090728,
#  0.18991195892212254,
#  0.18184717896568886,
#  0.17464106724578868,
#  0.16814841164144162,
#  0.16225601273978615,
#  0.15687425652026413,
#  0.15193121564644071,
#  0.14736843952337794,
#  0.14313789570431554,
#  0.13919971154708533,
#  0.13552048198124375,
#  0.13207198427591987,
#  0.12883018979113386,
#  0.12577449541280697,
#  0.12288711955018561,
#  0.12015262284790207,
#  0.1175575244384373,
#  0.11508999212203937,
#  0.11273959028608095,
#  0.11049707331437099,
#  0.1083542151281503,
#  0.10630366764499737,
#  0.1043388425480395,
#  0.1024538119718693,
#  0.10064322463707698,
#  0.09890223467661702,
#  0.09722644094810277,
#  0.09561183505584314,
#  0.0940547566439471,
#  0.012675305049695185,
#  0.012649360207409917,
#  0.012623525235430129,
#  0.012597799434689317,
#  0.012572182112025989,
#  0.012546672580121649,
#  0.012521270157439656,
#  0.012495974168164739,
#  0.012470783942143395,
#  0.012445698814824884,
#  0.012420718127203087,
#  0.012395841225759006,
#  0.012371067462403984,
#  0.012346396194423638,
#  0.012321826784422502,
#  0.012297358600269311,
#  0.012272991015042955,
#  0.012248723406979146,
#  0.012224555159417708,
#  0.01220048566075045,
#  0.012176514304369786,
#  0.012152640488617873,
#  0.012128863616736454,
#  0.012105183096817237,
#  0.012081598341752908,
#  0.012058108769188737,
#  0.012034713801474748,
#  0.012011412865618454,
#  0.011988205393238223,
#  0.011965090820517088,
#  0.011942068588157247,
#  0.01191913814133496,
#  0.011896298929656123,
#  0.011873550407112219,
#  0.011850892032036953,
#  0.01182832326706326,
#  0.0118058435790809,
#  0.01178345243919454,
#  0.011761149322682282,
#  0.011738933708954747,
#  0.011716805081514596,
#  0.011694762927916519,
#  0.011672806739727684,
#  0.011650936012488781,
#  0.011629150245675214,
#  0.0116074489426591,
#  0.011585831610671438,
#  0.011564297760764885,
#  0.011542846907776846,
#  0.011521478570293031,
#  0.011500192270611498,
#  0.011478987534706948]

# %%
plt.plot(error_list)

# %%
opt_theta
# Out:
# array([[5.38282715],
#        [1.19101276],
#        [1.12250365]])

# %%
x1_rv = np.arange(-4, 5)

# %%
x2_rv = - (opt_theta[0] + opt_theta[1]*x1_rv) / opt_theta[2]

# %%
plt.scatter(X[:, 0], X[:, 1], c = y.reshape(-1,)) #this is for y is m,1 500,1 so we reshape it
plt.plot(x1_rv, x2_rv)
plt.show()

# %%
y_pred = hypothesis(X_test, opt_theta)

# %%
opt_theta
# Out:
# array([[5.38282715],
#        [1.19101276],
#        [1.12250365]])

# %%
y_pred
# Out:
# array([[6.12635398e-03],
#        [9.97997305e-01],
#        [9.90442410e-01],
#        [3.49723599e-04],
#        [4.14752225e-03],
#        [9.99484263e-01],
#        [3.57390457e-03],
#        [9.45349263e-01],
#        [9.29843826e-01],
#        [9.99184065e-01],
#        [6.94650862e-03],
#        [9.36646736e-01],
#        [9.99647988e-01],
#        [9.95582814e-01],
#        [1.12135199e-02],
#        [9.96776109e-01],
#        [9.71831593e-01],
#        [9.52496543e-01],
#        [1.36671932e-04],
#        [2.90688245e-04],
#        [1.72841547e-03],
#        [8.34083385e-01],
#        [2.02202197e-03],
#        [7.89580669e-03],
#        [9.81868757e-01],
#        [1.26777873e-04],
#        [9.99398486e-01],
#        [9.98131430e-01],
#        [9.65930028e-05],
#        [9.98169515e-01],
#        [9.93665926e-01],
#        [6.23031432e-01],
#        [2.49374132e-04],
#        [9.97859652e-01],
#        [9.95565527e-01],
#        [8.52537861e-04],
#        [9.90518504e-01],
#        [5.04664758e-04],
#        [4.11651704e-03],
#        [2.66804690e-03],
#        [9.97011074e-01],
#        [8.02610135e-04],
#        [9.92917932e-01],
#        [9.06799547e-04],
#        [1.77846201e-04],
#        [9.76873166e-01],
#        [2.47198212e-04],
#        [1.33409119e-03],
#        [5.44045458e-04],
#        [9.95702125e-01],
#        [1.50444619e-04],
#        [1.33217511e-03],
#        [7.26228744e-04],
#        [9.84198659e-01],
#        [7.27821988e-04],
#        [3.47526141e-03],
#        [2.78404400e-03],
#        [2.77877015e-02],
#        [5.08755130e-03],
#        [9.96086747e-01],
#        [8.75292492e-04],
#        [9.93189329e-01],
#        [9.97271891e-01],
#        [9.51064236e-01],
#        [9.94262798e-01],
#        [9.96128083e-01],
#        [1.20493534e-03],
#        [2.79565358e-02],
#        [3.29437809e-04],
#        [9.96193146e-01],
#        [4.68579552e-04],
#        [9.95234490e-01],
#        [9.97570941e-01],
#        [9.99518597e-01],
#        [9.90544414e-01],
#        [4.26218742e-03],
#        [9.97762421e-01],
#        [9.98131750e-01],
#        [9.99491789e-01],
#        [8.26800588e-04],
#        [2.02032765e-04],
#        [9.99712923e-01],
#        [9.09395043e-01],
#        [1.11025695e-03],
#        [3.57015495e-04],
#        [1.44526350e-03],
#        [9.93952876e-01],
#        [9.99822081e-01],
#        [9.97647049e-01],
#        [9.96806366e-01],
#        [3.72399608e-03],
#        [9.91484614e-01],
#        [8.58351935e-03],
#        [3.86180465e-04],
#        [2.21113357e-02],
#        [9.96803086e-01],
#        [9.89158439e-01],
#        [4.33003833e-02],
#        [5.35199032e-03],
#        [2.11663427e-03],
#        [9.94449844e-01],
#        [9.86088318e-01],
#        [1.78885739e-03],
#        [9.75265648e-01],
#        [9.91876736e-01],
#        [5.65932965e-03],
#        [9.42405634e-01],
#        [9.99337616e-01],
#        [1.62352715e-02],
#        [7.14074893e-05],
#        [9.97291918e-01],
#        [9.59280099e-01],
#        [6.89419204e-03],
#        [9.72878652e-01],
#        [9.67739862e-01],
#        [7.27132820e-04],
#        [9.97653134e-01],
#        [1.57296581e-04],
#        [9.86495378e-01],
#        [3.38726487e-03],
#        [1.43223920e-01],
#        [9.49064649e-04],
#        [3.44995656e-03],
#        [9.99057590e-01],
#        [7.94464040e-04],
#        [9.90564402e-01],
#        [3.35371406e-03],
#        [9.90072220e-01],
#        [8.29079866e-04],
#        [9.92034610e-01],
#        [5.08425369e-04],
#        [2.46593022e-03],
#        [9.97139666e-01],
#        [9.98295293e-01],
#        [4.29738634e-05],
#        [9.88554848e-01],
#        [9.95792571e-01],
#        [9.99879368e-01],
#        [2.35295666e-03],
#        [9.99273496e-01],
#        [1.44116879e-03],
#        [9.17741934e-01],
#        [9.96379534e-01],
#        [6.20689516e-04],
#        [9.88402725e-01],
#        [9.82910999e-01],
#        [1.73232112e-03],
#        [9.93788178e-01],
#        [9.91789504e-01],
#        [9.94673648e-03],
#        [9.19332100e-01],
#        [9.20998430e-01],
#        [9.89052477e-01],
#        [2.58459511e-03],
#        [9.97620845e-01],
#        [9.98862031e-01],
#        [2.31908561e-03],
#        [1.73441722e-04],
#        [8.32539071e-01],
#        [7.73371285e-03],
#        [3.48146056e-04],
#        [8.93796049e-01],
#        [9.97288727e-01],
#        [9.96126439e-01],
#        [1.03777664e-02]])

# %%
y_pred = np.round(y_pred).astype('int')
#this is just rounding off and taking val to  int

# %%
# Accuracy
(y_pred == y_test).mean()
# Out:
# 1.0

# %% [markdown]
# # sklearn Logistic Reg

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
ypred = model.predict(X_test)

# %%
model.intercept_
# Out:
# array([9.25520576])

# %%
model.coef_
# Out:
# array([[-1.21790800e-06,  5.60363665e-01,  1.72723229e+00]])
