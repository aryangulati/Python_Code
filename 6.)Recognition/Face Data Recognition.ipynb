# %%
import os
import numpy as np
import cv2

# %%
dataset_path = "./data/"

# %%
os.listdir(dataset_path)#operating system tellme list directory that the path have!
# Out:
# ['ARYAN.npy', 'robert.npy']

# %%
for fx in os.listdir(dataset_path):#operating system tellme list directory
    if fx.endswith(".npy"):
        print(fx)
# Out:
# ARYAN.npy
# robert.npy

# %%
face_data = []
labels = [] #y values in kNN

# %%
for fx in os.listdir(dataset_path):#operating system tellme list directory
    if fx.endswith(".npy"):
        l = fx.split(".")[0] #split by . and taking 0th part
        print(l)
        np.load()
# Out:
# ARYAN
# robert

# %%
for fx in os.listdir(dataset_path):#operating system tellme list directory
    if fx.endswith(".npy"):
        l = fx.split(".")[0] #split by . and taking 0th part-->Name
        
        face_item=np.load(dataset_path+ fx) #storing imgs in numpy format --> Images
        print(face.shape)
        print(l)
        #break #here is for running one time
        face_data.append(face_item)
        #labels.append(l) here we not have to do this we have to append it 64 times
        # appending labels #times => faces
        for i in range(face_item.shape[0]):
            labels.append(l)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a0a713c4ab59> in <module>
#       4
#       5         face_item=np.load(dataset_path+ fx) #storing imgs in numpy format --> Images
# ----> 6         print(face.shape)
#       7         print(l)
#       8         #break #here is for running one time
#
# NameError: name 'face' is not defined

# %%
face_data
# Out:
# []

# %%
face_data[0].shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-db57cddaf6c7> in <module>
# ----> 1 face_data[0].shape
#
# IndexError: list index out of range

# %%
face_data[1].shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-c8f156b3443e> in <module>
# ----> 1 face_data[1].shape
#
# IndexError: list index out of range

# %%
labels
# Out:
# []

# %%
import os
import numpy as np
import cv2

dataset_path = "./data/"

face_data = []
labels = []

for fx in os.listdir(dataset_path):
    if fx.endswith(".npy"):
        l = fx.split(".")[0]
        
        face_item = np.load(dataset_path + fx)
        print(face_item.shape)
        print(l)
        
        face_data.append(face_item)
        # appending labels #times => faces
        for i in range(face_item.shape[0]):
            labels.append(l)


X = np.concatenate(face_data, axis =0)
y = np.array(labels)
# Out:
# (276, 30000)
# ARYAN
# (585, 30000)
# robert

# %%
labels
# Out:
# ['ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'ARYAN',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert',
#  'robert']

# %%
face_data[1].shape
# Out:
# (585, 30000)

# %%
face_data[0].shape
# Out:
# (276, 30000)

# %%
585+276
# Out:
# 861

# %%
face_data #we have concat data from nparray to x
#according  axis=0
# Out:
# [array([[21, 12, 17, ..., 41, 38, 30],
#         [47, 61, 63, ..., 13, 16, 20],
#         [47, 61, 63, ..., 13, 16, 20],
#         ...,
#         [25, 16, 23, ..., 52, 48, 36],
#         [22, 14, 15, ..., 48, 43, 35],
#         [22, 14, 15, ..., 48, 43, 35]], dtype=uint8),
#  array([[255, 254, 254, ...,  36,  11,  17],
#         [255, 255, 253, ...,  49,  24,  22],
#         [255, 255, 250, ...,  28,  13,   8],
#         ...,
#         [254, 240, 244, ..., 189, 159, 142],
#         [255, 247, 248, ...,  37,  24,  22],
#         [255, 244, 244, ...,  81,  62,  53]], dtype=uint8)]

# %%
#below we are concaticating the no. of images

# %%
X = np.concatenate(face_data, axis =0) 

#axis=0 is index row
#axis =1 is col

# %%
X
# Out:
# array([[ 21,  12,  17, ...,  41,  38,  30],
#        [ 47,  61,  63, ...,  13,  16,  20],
#        [ 47,  61,  63, ...,  13,  16,  20],
#        ...,
#        [254, 240, 244, ..., 189, 159, 142],
#        [255, 247, 248, ...,  37,  24,  22],
#        [255, 244, 244, ...,  81,  62,  53]], dtype=uint8)

# %%
X.shape
# Out:
# (861, 30000)

# %%
y=np.array(labels)

# %%
y
# Out:
# array(['ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN', 'ARYAN',
#        'ARYAN', 'ARYAN', 'ARYAN', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert', 'robert',
#        'robert', 'robert', 'robert', 'robert', 'robert'], dtype='<U6')

# %%
y.shape
# Out:
# (861,)

# %%
cv2.putText()
