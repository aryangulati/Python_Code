# %%
import os #its for operating system
#we can interact with operating sys

# %%
os.listdir() #that will give u all the python folder 
#inside your current directories
# Out:
# ['.ipynb_checkpoints',
#  'customname.py',
#  'mosule and package.ipynb',
#  'PYTHON_BASICS_1.ipynb',
#  'PYTHON_BASICS_2.ipynb',
#  'PYTHON_BASICS_3.ipynb',
#  '__pycache__']

# %%
os.listdir("../") #this will give you one dir backword
# Out:
# ['.git', '.gitignore', 'filerunfirstpython', 'PYTHON_BASICS', 'README.md']

# %%
os.getcwd() #where we are (give current dir)
# Out:
# 'C:\\Users\\lenovo\\Desktop\\Python_Master\\PYTHON_BASICS'

# %%
import random 
# genetare random no

# %%
5*random.random()+10 #see this func doc
# Out:
# 12.855749652553357

# %%
random.randint(1,10) # intrandom val
# Out:
# 6

# %%
import name2 #not found
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-63efeb6e265d> in <module>
# ----> 1 import name2 #not found
#
# ModuleNotFoundError: No module named 'name2'

# %%
import customname 
#we can also import our file on Pypi

# %%
customname.hello_to_all("aryan")
# Out:
# aryan says hello to all

# %%
customname.bye("ar")
# Out:
# ar say bye to all

# %%
dir(customname) #list of all func in module
#all other are hidden things
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'add',
#  'bye',
#  'hello_to_all',
#  'print_name']

# %%
customname.add(9,10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b24a4bbe73f6> in <module>
# ----> 1 customname.add(9,10)
#
# NameError: name 'customname' is not defined

# %%
#sometimes we are imporing only one func
#from customname import hello_to _all
#sometimes we are imporing all
#from customname import *

# %%
customname.print_name()
#<function customname.print_name()>
# Out:
# customname

# %%
customname.__name__
# Out:
# 'customname'

# %%
import math

# %% [markdown]
# # Exception handling

# %%
a=10
b=0

# %%
a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-aae42d317509> in <module>
# ----> 1 a/b
#
# ZeroDivisionError: division by zero

# %%
try:
    a/b
except ZeroDivisionError:
    print("zero error")
except:
    print("general errror")
print("yeahhh exepted")
# Out:
# zero error
# yeahhh exepted

# %%
l=[1,2,3]

# %%
l.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-00da2dd6f77a> in <module>
# ----> 1 l.split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
try:
    l.split()
except ZeroDivisionError:
    print("zero error")
    
except AttributeError:
    print("custom attribute error")
except:
    print("general errror")
else:
    print("no error int he code")
print("yeahhh exepted")
# Out:
# custom attribute error
# yeahhh exepted

# %%
try:
    l.sort()
except ZeroDivisionError:
    print("aero error")
except:
    print("general errror")
else:
    print("no error in the code")
print("yeahhh exepted")
# Out:
# no error in the code
# yeahhh exepted

# %%
dir(__builtins__) #Built-in functions, exceptions, and other objects.
#type of errors
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'WindowsError',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'all',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'breakpoint',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %%
try:
    l.split()
except ZeroDivisionError:
    print("aero error")
except:
    print("general errror")
else:
    print("no error int he code")
finally:
    #always have this block executed 
    #you have error or not
    print("i will always excute after all except")
    
    
    
    
    
    
    
    
    
    
print("yeahhh exepted 10000 line of code")
# Out:
# general errror
# i will always excute after all except
# yeahhh exepted 10000 line of code

# %%
name=input("input ur name :")

try:
    if(len(name)<3):
        raise Exception
#         name+lastmname
#         email(name)#why would i send email to that person who has given wrong email
except:
    print("name shouldnt be less than 3")
# Out:
# input ur name :mo
# name shouldnt be less than 3

# %%
#https://docs.python.org/3/tutorial/errors.html
