# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.sort_values(by="petal_length")[:50]
#so whole data is set according to petal length
#sort whole data frame
#we have to do sort in no. according to this data not categorical
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# ...

# %%
df.sort_values(by="sepal_width")[:50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 41            4.5          2.3           1.3          0.3      Iris-setosa
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 93            5.0          2.3           3.3          1.0  Iris-versicolor
# 87            6.3          2.3           4.4          1.3  Iris-versicolor
# 81            5.5          2.4           3.7          1.0  Iris-versicolor
# 80            5.5          2.4           3.8          1.1  Iris-versicolor
# 57            4.9          2.4           3.3          1.0  Iris-versicolor
# ...

# %%
df.sort_values(by=["petal_length","petal_width"])[:50]
#first sort petallength then petal width 
#if we have to pass two feature then pass a list in DataFrame
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# ...

# %%
df["petal_length"].std()
#axis=0 is index row
#axis =1 is col
# Out:
# 1.7644204199522626

# %%
df.mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
abs(-10)
# Out:
# 10

# %% [markdown]
# ## Group by

# %%
byspecies=df.groupby(by="species") # basically its grouping whole df only col we have passed
#whole df grouping by species
#you can only group by categorically
#or
#df.groupby("species").min() #instead of creating an obj

# %%
byspecies
#group by object
#itwill not show anything
#till u pass aggregate function-max,min.median

# %%
byspecies.max()
#so species here is grouped by
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa               5.8          4.4           1.9          0.6
# Iris-versicolor           7.0          3.4           5.1          1.8
# Iris-virginica            7.9          3.8           6.9          2.5

# %%
byspecies.min()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa               4.3          2.3           1.0          0.1
# Iris-versicolor           4.9          2.0           3.0          1.0
# Iris-virginica            4.9          2.2           4.5          1.4

# %%
byspecies.mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %%
byspecies.describe().T
# Out:
# species             Iris-setosa  Iris-versicolor  Iris-virginica
# sepal_length count    50.000000        50.000000       50.000000
#              mean      5.006000         5.936000        6.588000
#              std       0.352490         0.516171        0.635880
#              min       4.300000         4.900000        4.900000
#              25%       4.800000         5.600000        6.225000
#              50%       5.000000         5.900000        6.500000
#              75%       5.200000         6.300000        6.900000
#              max       5.800000         7.000000        7.900000
# sepal_width  count    50.000000        50.000000       50.000000
#              mean      3.418000         2.770000        2.974000
#              std       0.381024         0.313798        0.322497
#              min       2.300000         2.000000        2.200000
#              25%       3.125000         2.525000        2.800000
# ...

# %% [markdown]
# ### Create a CSV file from dataframe

# %%
#create csv ==> to_csv()
df.to_csv("my_file.csv",index=False) #create a new csv file

# %%
pd.read_csv("my_file.csv") #its saving two indexes so we do above false to remove
#
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      new_column
# 0          1.96
# 1          1.96
# 2          1.69
# ...

# %%
#pd.concat() and pass sequence of 2 df obj
#pd.merge()
#see python.org 
#data frame merge

# %%
df["petal_length"].apply(int)
#so it convert in integer
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    5
# 146    5
# 147    5
# 148    5
# 149    5
# Name: petal_length, Length: 150, dtype: int64

# %%
def my_custom(x):
    return x**2

# %%
df["petal_length"].apply(my_custom)
# Out:
# 0       1.96
# 1       1.96
# 2       1.69
# 3       2.25
# 4       1.96
#        ...
# 145    27.04
# 146    25.00
# 147    27.04
# 148    29.16
# 149    26.01
# Name: petal_length, Length: 150, dtype: float64

# %%
df["new_column"]=df["petal_length"].apply(my_custom)

# %%
len #len is aslo a func
# Out:
# <function len(obj, /)>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      new_column
# 0          1.96
# 1          1.96
# 2          1.69
# ...

# %% [markdown]
# # Data Visualisation
# able to plot visualize something

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0C47E790>,
# ...
#       dtype=object)

# %%
#EDA using pandas ,matplotlib,seaborn depending on data
df['petal_length'].hist()
#or 
#df.hist(column="petal_length")

# %%
df.hist(column="petal_length")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0C574C88>]],
#       dtype=object)

# %%
df[df['species']=="Iris-setosa"].hist('petal_length',bins=10) #size of box is bin
#this means only taking iris setosa flower df['species']=="Iris-setosa"
#then drawing histogram for petal length of setosa
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x106BDD90>]],
#       dtype=object)

# %%
#matplotlib is more focussed towards DVisulization
df.plot.kde()

# %%
df.plot.box()

# %%
df.plot.bar()

# %%
df["petal_length"].plot.kde()

# %%
df.plot.scatter(x="petal_length",y="petal_width")

# %%
df.plot.line()

# %%
#df.plot. explore more...
