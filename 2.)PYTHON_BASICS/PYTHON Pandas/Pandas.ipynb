# %%
import pandas as pd
import numpy as np

# %%
#Working with Toy Dataset
#download Iris Flower Dataset
#DATAFRAME - obj in pandas(dataype in pandas way of storing data)
df=pd.read_csv("./IRIS.csv")
#this is comma seprate value
#their is also one tsv- tab sperated val

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head()# first five rows of DataSet
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail() #last five rows of DataSet
#bydefault 5 rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
type(df)
#DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
#convert  dataFrame-->Numpy
#use==> .values
iris=pd.read_csv("./IRIS.csv").values
#./ this represent current dir

# %%
iris[:,:-1] #removing last column
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3.0, 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.0, 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.0, 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3.0, 1.4, 0.1],
#        [4.3, 3.0, 1.1, 0.1],
#        [5.8, 4.0, 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1.0, 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5.0, 3.0, 1.6, 0.2],
#        [5.0, 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
#exctracting all col ele
#and all ele in columns
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df["species"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: species, Length: 150, dtype: object

# %%
df[["sepal_length","sepal_width"]]
# Out:
#      sepal_length  sepal_width
# 0             5.1          3.5
# 1             4.9          3.0
# 2             4.7          3.2
# 3             4.6          3.1
# 4             5.0          3.6
# ..            ...          ...
# 145           6.7          3.0
# 146           6.3          2.5
# 147           6.5          3.0
# 148           6.2          3.4
# 149           5.9          3.0
#
# [150 rows x 2 columns]

# %%
type(df['species'])
#single thing then series
# Out:
# pandas.core.series.Series

# %%
type(df[["sepal_length","sepal_width"]])
#Combination of two or more series is knoown as DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
#Series and DataFrame making urself
#by passing list
#we can also change indexes accordingly !!
c=pd.Series([1,10,20,30],index="a b c d".split())

# %%
#making DataFrame from Numpy Arrays
arr=np.random.randint(1,100,size=(175,3))

# %%
pd.DataFrame(arr,columns=['f1','f2','f3'])
#changing name of columns
# Out:
#      f1  f2  f3
# 0    92  30  66
# 1    27  19  77
# 2    99  12  87
# 3    97  31  74
# 4    88  75  25
# ..   ..  ..  ..
# 170  63  19  46
# 171  20  69  42
# 172  28  14  14
# 173  44  42  27
# 174  53  67  38
#
# [175 rows x 3 columns]

# %%
pd.DataFrame() #making empty data frame
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(arr[:,:-1],columns=['f1','f2'])
#removing one column (f3) from DataSet
# Out:
#      f1  f2
# 0    92  30
# 1    27  19
# 2    99  12
# 3    97  31
# 4    88  75
# ..   ..  ..
# 170  63  19
# 171  20  69
# 172  28  14
# 173  44  42
# 174  53  67
#
# [175 rows x 2 columns]

# %%
#how to create DataFrame using list
data=[["aryan",10],["aryan2",11],["aryan3",12]]
df=pd.DataFrame(data,columns=["Name","Age"])
df
# Out:
#      Name  Age
# 0   aryan   10
# 1  aryan2   11
# 2  aryan3   12

# %%
data={"Name":["aryan","aryan1","aryan2"],"age":["11","21","13"]}
df1 = pd.DataFrame(data) 
df1
# Out:
#      Name age
# 0   aryan  11
# 1  aryan1  21
# 2  aryan2  13

# %%
data = {'Name':["abc","cbd","dbc","efh"], 'roll no.':[12,2,3,4]}
df2=pd.DataFrame(data,index=["01","02","03","04"])
df2
# Out:
#    Name  roll no.
# 01  abc        12
# 02  cbd         2
# 03  dbc         3
# 04  efh         4

# %%
d=[{"a":1,"b":2,"c":3},{"a":10,"b":20,"c":30}]
df3=pd.DataFrame(d)
df3#you can also make indexing according to you
# Out:
#     a   b   c
# 0   1   2   3
# 1  10  20  30

# %%
d = {'one' : pd.Series([10, 20, 30, 40], index =['a', 'b', 'c', 'd']), 
      'two' : pd.Series([10, 20, 30, 40], index =['a', 'b', 'c', 'd'])} 
  
# creates Dataframe. 
df = pd.DataFrame(d) 
  
# print the data. 
df
# Out:
#    one  two
# a   10   10
# b   20   20
# c   30   30
# d   40   40

# %%
#how to create data frame using dictionaries
dicti={"name":["aryan","yourname","someother"],
     "car":["BMW","AUDI","porsche"],
     "score":["25","24","23"]}
df5=pd.DataFrame(dicti)
df5
# Out:
#         name      car score
# 0      aryan      BMW    25
# 1   yourname     AUDI    24
# 2  someother  porsche    23

# %%
#if u want row then u pass this
df[0]#but errror
#so to access rows we can use afunc ==>loc()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lenovo\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-43c7332330e6> in <module>
# ...

# %%
df.loc[145]
# Out:
# sepal_length               6.7
# sepal_width                  3
# petal_length               5.2
# petal_width                2.3
# species         Iris-virginica
# Name: 145, dtype: object

# %%
df.loc[0] #particular index of ROWs
# Out:
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# species         Iris-setosa
# Name: 0, dtype: object

# %%
df.iloc[0] #integer loctaion same work asloc()
#useful when we have indx in character
# Out:
# sepal_length            5.1
# sepal_width             3.5
# petal_length            1.4
# petal_width             0.2
# species         Iris-setosa
# Name: 0, dtype: object

# %%
#df[0] it try to aceess column
df.loc[0:5] #this is indexed based
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa

# %%
df.iloc[0:5,0:4]
#this is integer based
#see both table above one is including last val but not in iloc
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      5.100000          3.5           1.4          0.2
# 1      4.900000          3.0           1.4          0.2
# 2      5.869748          3.2           1.3          0.2
# 3      4.600000          3.1           1.5          0.2
# 4      5.000000          3.6           NaN          0.2

# %%
type(df.iloc[1])
#series
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[:5])
#DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
#to convert it in numpy
print(df.iloc[:5].values)
print("converted to numpy")
print(df.iloc[5].values)
# Out:
# [[5.1 3.5 1.4 0.2 'Iris-setosa']
#  [4.9 3.0 1.4 0.2 'Iris-setosa']
#  [4.7 3.2 1.3 0.2 'Iris-setosa']
#  [4.6 3.1 1.5 0.2 'Iris-setosa']
#  [5.0 3.6 1.4 0.2 'Iris-setosa']]
# converted to numpy
# [5.4 3.9 1.7 0.4 'Iris-setosa']

# %%
#function that Generate descriptive statistics
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#df["total value"]=sum of all 4 val
df["total value"]=df["sepal_length"]+df["sepal_width"]+df["petal_length"]+df["petal_width"]

# %%
df
#if u have col name of same as total val then it will be overwrite
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      total value
# 0           10.2
# 1            9.5
# 2            9.4
# ...

# %%
#drop col,row or index
df.drop(columns=["total value"],inplace=True)
#df.drop(columns=["total value"],inplace=True) by default inplace is FALSE
#inplace will change(s) Data with original DataFrame

# %%
#if their is  any nullor Nan val-Not a number 
#it give True or False 
df.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isna().sum() #total Nan values
#idea is to fill the nan values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print(True+True) #True=1 ,False=0
print(False+True+False)
# Out:
# 2
# 1

# %%
df["species"].unique()
#Total number of unique elements
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["species"].nunique()
#no of unique
# Out:
# 3

# %%
df["species"].value_counts()
#telling quantity of differnt things
#and this is highly balanced dataset
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
# extract all rows where you have Iris-setosa flower
#masking
df[df["species"]=="Iris-setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
# extract all rows where sepal_len < 5.3 and sepal_width >3.5
df[(df['sepal_length'] <5.3) & (df['sepal_width']>3.5)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa

# %%
# extract all rows where sepal_len < 5.3
df[(df['sepal_length'] <5.3) & (df['sepal_width']>3.5)].reset_index()#.drop(columns=["index"])#then drop index column
#drop("index")
#we use iloc so no need
#in series we use this "&" not this 'and'
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width      species
# 0      4           5.0          3.6           1.4          0.2  Iris-setosa
# 1     19           5.1          3.8           1.5          0.3  Iris-setosa
# 2     21           5.1          3.7           1.5          0.4  Iris-setosa
# 3     22           4.6          3.6           1.0          0.2  Iris-setosa
# 4     32           5.2          4.1           1.5          0.1  Iris-setosa
# 5     44           5.1          3.8           1.9          0.4  Iris-setosa
# 6     46           5.1          3.8           1.6          0.2  Iris-setosa

# %%
#making DataSet which has Nan values

# %%
rows=np.random.randint(1,150,100)
col=np.random.randint(0,4,100)

# %%
rows
# Out:
# array([ 39,  79,  69,  29,  13,  52, 148,  82, 108,  78, 124,  23,  73,
#        132,  82,  31,  49,  37,  85,  68,  52,  92, 135,  75,  30,  87,
#        129, 112, 112,   5,  91,   2, 127,  34, 130,  64, 117,  47,  34,
#         71,  82,  73,  27,  59,   4,  35,  36,  62, 144,  28, 133, 102,
#        114,  87, 131,  44,  18,  82,   6,  44,  99,  68,  87, 140, 102,
#         49,  54, 125,  76, 104,  57, 129, 108,  16, 121, 126, 102,  43,
#        142,  90, 134,  66,  34, 103, 146,  45, 144,  74, 147, 106,  69,
#         53,  53,   4, 146,  41,  79,  17,  46,  50])

# %%
col
# Out:
# array([3, 3, 3, 3, 3, 2, 3, 0, 3, 3, 1, 2, 0, 3, 1, 2, 3, 3, 3, 1, 1, 1,
#        1, 1, 0, 1, 3, 2, 0, 3, 0, 0, 0, 3, 1, 2, 3, 0, 2, 2, 2, 3, 2, 1,
#        1, 3, 1, 2, 3, 1, 2, 3, 0, 0, 1, 0, 1, 3, 1, 2, 2, 3, 2, 2, 2, 1,
#        2, 0, 3, 3, 1, 0, 2, 2, 2, 0, 2, 0, 0, 0, 1, 3, 1, 3, 3, 3, 2, 0,
#        1, 3, 3, 1, 0, 1, 1, 0, 0, 3, 3, 0])

# %%
#manually entering NaN val
#changing val in dataframe to nan val
for i in range(100):
    df.iloc[rows[i],col[i]]=np.nan
    #just picked random numbers
    #it could be any no from 150 rows

# %%
df.iloc[rows[2],col[0]]
# Out:
# nan

# %%
df[:150]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             NaN          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          NaN           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          NaN           5.0          NaN  Iris-virginica
# 147           6.5          NaN           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          NaN  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# sepal_length    31
# sepal_width     27
# petal_length    16
# petal_width     19
# species          0
# dtype: int64

# %% [markdown]
# # dealing with nan values
# - remove nan
# - remove col
# - Impute nan val(Mean)

# %%
#Impute nan val
df["sepal_length"].mean()
# Out:
# 5.869747899159663

# %%
df["sepal_length"].fillna(value="ABC") #it will put abc val in place of Nan
#their is also a function dropna() but we dont use here
# Out:
# 0      5.1
# 1      4.9
# 2      ABC
# 3      4.6
# 4        5
#       ...
# 145    6.7
# 146    ABC
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: object

# %%
df['sepal_length'].fillna( value=df['sepal_length'].mean()  , inplace=True)
#replace nan value with its mean

# %%
df['sepal_length'].fillna( value=df['sepal_length'].mean())[:50]
# Out:
# 0     5.100000
# 1     4.900000
# 2     5.869748
# 3     4.600000
# 4     5.000000
# 5     5.400000
# 6     5.869748
# 7     5.000000
# 8     4.400000
# 9     4.900000
# 10    5.869748
# 11    4.800000
# 12    5.869748
# 13    4.300000
# 14    5.800000
# 15    5.700000
# 16    5.400000
# 17    5.869748
# 18    5.700000
# 19    5.100000
# 20    5.400000
# 21    5.100000
# 22    4.600000
# 23    5.100000
# 24    5.869748
# 25    5.869748
# 26    5.000000
# 27    5.200000
# 28    5.869748
# 29    4.700000
# 30    4.800000
# 31    5.400000
# 32    5.869748
# 33    5.500000
# 34    4.900000
# 35    5.000000
# 36    5.500000
# 37    4.900000
# 38    4.400000
# 39    5.869748
# 40    5.000000
# 41    5.869748
# 42    5.869748
# 43    5.869748
# 44    5.100000
# 45    5.869748
# 46    5.100000
# 47    4.600000
# 48    5.300000
# 49    5.869748
# Name: sepal_length, dtype: float64

# %%
df.isna().sum()
#so Nan val in sepal_length become 0
# Out:
# sepal_length     0
# sepal_width     27
# petal_length    16
# petal_width     19
# species          0
# dtype: int64

# %%
df.iloc[[2,7,3,8,1,9,80]]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 2       5.869748          3.2           1.3          0.2      Iris-setosa
# 7       5.000000          NaN           1.5          0.2      Iris-setosa
# 3       4.600000          3.1           1.5          0.2      Iris-setosa
# 8       4.400000          NaN           1.4          NaN      Iris-setosa
# 1       4.900000          3.0           1.4          0.2      Iris-setosa
# 9       4.900000          3.1           1.5          0.1      Iris-setosa
# 80      5.500000          2.4           3.8          1.1  Iris-versicolor

# %%
df.iloc[[2,7,3,8,1,9,80]]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 2       5.869748          3.2           1.3          0.2      Iris-setosa
# 7       5.000000          NaN           1.5          0.2      Iris-setosa
# 3       4.600000          3.1           1.5          0.2      Iris-setosa
# 8       4.400000          NaN           1.4          NaN      Iris-setosa
# 1       4.900000          3.0           1.4          0.2      Iris-setosa
# 9       4.900000          3.1           1.5          0.1      Iris-setosa
# 80      5.500000          2.4           3.8          1.1  Iris-versicolor
