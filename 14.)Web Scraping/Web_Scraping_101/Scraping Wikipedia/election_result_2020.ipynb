# %%
import pandas

wiki= pandas.read_html('https://en.wikipedia.org/wiki/2020_United_States_presidential_election')

# %%
wiki[1]
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                   ← 2016 November 3, 2020[a] 2024 →
# 2                                              ← 2016
# 3   538 members of the Electoral College270 electo...
# 4                                       Opinion polls
# 5                                             Turnout
# 6   Nominee Joe Biden Donald Trump Party Democrati...
# 7                                                 NaN
# 8                                             Nominee
# 9                                               Party
# 10                                         Home state
# 11                                       Running mate
# 12                                     Electoral vote
# 13                                     States carried
# 14                                       Popular vote
# 15                                         Percentage
# 16  Presidential election results map. Blue denote...
# 17  President before election Donald Trump Republi...
# 18  President before election Donald Trump Republican
#
#                                                     1             2   3
# 0                                                 NaN           NaN NaN
# 1                   ← 2016 November 3, 2020[a] 2024 →           NaN NaN
# 2                                 November 3, 2020[a]        2024 → NaN
# 3   538 members of the Electoral College270 electo...           NaN NaN
# 4                                       Opinion polls           NaN NaN
# 5                              66.7% (preliminary)[4]           NaN NaN
# 6   Nominee Joe Biden Donald Trump Party Democrati...           NaN NaN
# 7                                                 NaN           NaN NaN
# 8                                           Joe Biden  Donald Trump NaN
# 9                                          Democratic    Republican NaN
# 10                                           Delaware    Florida[b] NaN
# 11                                      Kamala Harris    Mike Pence NaN
# 12                                             306[c]        232[c] NaN
# 13                                    25 + DC + NE-02    25 + ME-02 NaN
# 14                                           81268867      74216747 NaN
# 15                                              51.3%         46.9% NaN
# 16  Presidential election results map. Blue denote...           NaN NaN
# 17  President before election Donald Trump Republi...           NaN NaN
# 18             Elected President Joe Biden Democratic           NaN NaN

# %%
wiki[2]
# Out:
#         0                    1       2
# 0  ← 2016  November 3, 2020[a]  2024 →

# %%
wiki[3]
# Out:
#                 0                1             2   3
# 0             NaN              NaN           NaN NaN
# 1         Nominee        Joe Biden  Donald Trump NaN
# 2           Party       Democratic    Republican NaN
# 3      Home state         Delaware    Florida[b] NaN
# 4    Running mate    Kamala Harris    Mike Pence NaN
# 5  Electoral vote           306[c]        232[c] NaN
# 6  States carried  25 + DC + NE-02    25 + ME-02 NaN
# 7    Popular vote         81268867      74216747 NaN
# 8      Percentage            51.3%         46.9% NaN

# %%
wiki[4]
# Out:
#                                                    0  \
# 0  President before election Donald Trump Republican
#
#                                         1
# 0  Elected President Joe Biden Democratic

# %%
election = wiki[4]
candidate_1 = election[1]
cand_1_name = candidate_1[1]
cand_1_name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-511e886e7d38> in <module>
#       1 election = wiki[4]
#       2 candidate_1 = election[1]
# ----> 3 cand_1_name = candidate_1[1]
#       4 cand_1_name
#
# ~\Anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\Anaconda\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# ~\Anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 1

# %%
election = wiki[4]
candidate_1 = election[1]
cand_1_name = candidate_1[1]
cand_1_votes = candidate_1[5]
cand_1_popular = candidate_1[7]

candidate_2 = election[2]
cand_2_name = candidate_2[1]
cand_2_votes = candidate_2[5]
cand_2_popular = candidate_2[7]

if cand_1_votes > cand_2_votes:
    print(cand_1_name, 'winner')
else:
    print(cand_2_name, 'winner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-7b36c367c092> in <module>
#       1 election = wiki[4]
#       2 candidate_1 = election[1]
# ----> 3 cand_1_name = candidate_1[1]
#       4 cand_1_votes = candidate_1[5]
#       5 cand_1_popular = candidate_1[7]
#
# ~\Anaconda\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\Anaconda\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# ~\Anaconda\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 1
