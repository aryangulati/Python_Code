# %%
from bs4 import BeautifulSoup
import requests

# %%
url="https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html"

# %%
res=requests.get(url)

# %%
BeautifulSoup(res.content)
# Out:
# <!DOCTYPE HTML>
# <html lang="en"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="https://cdn.ampproject.org" rel="dns-prefetch"/> <link href="https://images.livemint.com" rel="dns-prefetch"/> <link href="https://www.livemint.com" rel="dns-prefetch"/> <link href="https://www.google-analytics.com" rel="dns-prefetch"/> <link href="https://fonts.googleapis.com" rel="dns-prefetch"/> <link href="https://www.google.com" rel="dns-prefetch"/> <link href="https://ajax.googleapis.com" rel="dns-prefetch"/> <link href="https://players.brightcove.net" rel="dns-prefetch"/> <link href="https://www.googletagservices.com" rel="dns-prefetch"/> <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/> <link href="https://static.adsafeprotected.com" rel="dns-prefetch"/> <link href="https://fonts.googleapis.com" rel="dns-prefetch"/> <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/> <link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/> <link href="//adservice.google.co.in" rel="dns-prefetch"/> <link href="//adservice.google.com" rel="dns-prefetch"/><link as="font" crossorigin="" href="/fonts/PT_Serif-Web-Regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="" href="/fonts/PT_Serif-Web-Bold.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="" href="/fonts/Lato-Regular.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="" href="/fonts/Lato-Bold.woff2" rel="preload" type="font/woff2"/><script type="text/javascript">var _sf_startpt = (new Date()).getTime();</script>
# <link href="https://images.livemint.com/rw/PortalConfig/LiveMint/static_content/images/v2/livemint_favicon.png" rel="icon"/>
# <title>Full text of PM Narendra Modi's speech on lockdown, stimulus package</title><meta content="PM Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be 'totally different' from the previous phases.He also announced the long-awaited stimulus package of Rs20 trillion for businesses and workers to soften the devastating blow from the coronavirus lockdown" name="description"/><meta content="Narendra Modi,coronavirus,coronavirus pandemic,Narendra Modi speech on lockdown,Narendra Modi speech stimulus package,lockdown 4.0,Indian economy,coronavirus impact on Indian economy,Full text of PM Narendra Modi speech,Narendra Modi address to nation,text of PM Modi address to nation" name="keywords"/><meta content="Narendra Modi,coronavirus,coronavirus pandemic,Narendra Modi speech on lockdown,Narendra Modi speech stimulus package,lockdown 4.0,Indian economy,coronavirus impact on Indian economy,Full text of PM Narendra Modi speech,Narendra Modi address to nation,text of PM Modi address to nation" name="news_keywords"/><link href="https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html" rel="canonical"/><link href="android-app://com.htmedia.mint/https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html" rel="alternate"/><link href="https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package/amp-11589312482447.html" rel="amphtml"/><meta content="Full text of PM Narendra Modi's speech on lockdown, stimulus package" property="og:title"/><meta content="https://images.livemint.com/img/2020/05/12/600x338/20200512277L_1589297156966_1589312829681.jpg" property="og:image"/><meta content="article" property="og:type"/><meta content="https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html" property="og:url"/><meta content="Livemint" property="og:site_name"/><meta content="PM Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be 'totally different' from the previous phases.He also announced the long-awaited stimulus package of Rs20 trillion for businesses and workers to soften the devastating blow from the coronavirus lockdown" property="og:description"/><meta content="Full text of PM Narendra Modi's speech on lockdown, stimulus package" name="tweetmeme-title"/><link href="https://images.livemint.com/img/2020/05/12/600x338/20200512277L_1589297156966_1589312829681.jpg" rel="image_src"/><meta content="summary_large_image" name="twitter:card"/><meta content="@livemint" name="twitter:site"/><meta content="livemint.com" name="twitter:domain"/><meta content="https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html" name="twitter:url"/><meta content="Full text of PM Narendra Modi's speech on lockdown, stimulus package" name="twitter:title"/><meta content="PM Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be 'totally different' from the previous phases.He also announced the long-awaited stimulus package of Rs20 trillion for businesses and workers to soften the devastating blow from the coronavirus lockdown" name="twitter:description"/><meta content="https://images.livemint.com/img/2020/05/12/600x338/20200512277L_1589297156966_1589312829681.jpg" name="twitter:image:src"/><meta content="2020-05-13T01:22:02+05:30" property="article:published_time"/><meta content="News" property="article:section"/><meta content="Staff Writer" name="author"/>
# <meta content="2020-05-13T01:22:03+05:30" name="Last-Modified"/><meta content="Wed, May 13, 2020" name="Last-Modified-Date"/><meta content="2020-05-13T01:22:03+05:30" name="Last-Modified-Time"/><meta content="2020-05-13T01:22:03+05:30" http-equiv="Last-Modified"/>
# <meta content="11589312482447" name="storyid"/><meta content="News" name="section"/><meta content="2020-05-13T01:22:03+05:30" name="last-updated"/>
# <script type="application/ld+json">
# {
# 	"@context": "http://schema.org",
# 	"@type": "BreadcrumbList",
# 	"itemListElement": [{"@type": "ListItem","position": 1,"item": {"@id": "https://www.livemint.com/","name": "Home"}},
# 		{
# 			"@type": "ListItem",
# 			"position": 2,
# 			"item": {
# 				"@id": "https://www.livemint.com/News",
# 				"name": "News"
# 			}
# 		}
# 			, 			{
# 				"@type": "ListItem",
# 				"position": 3,
# 				"item": {
# 					"@id": "https://www.livemint.com/News/India",
# 					"name": "India"
# 				}
# 			}
# 			,
# 			{
# 				"@type": "ListItem",
# 				"position": 4,
# 				"item": {
# 					"name": "Full text of PM Narendra Modi's speech on lockdown, stimulus package"
# 				}
# 			}
# 	]
# }
# </script><script type="application/ld+json">
# {
# 	"@context": "http://schema.org",
# 	"@type": "NewsArticle",
# 	"mainEntityOfPage": "https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html",
# 	"inLanguage": "en",
# 	"headline": "Full text of PM Narendra Modi's speech on lockdown, stimulus package",
# 	"description": "PM Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be 'totally different' from the previous phases.He also announced the long-awaited stimulus package of Rs20 trillion for businesses and workers to soften the devastating blow from the coronavirus lockdown",
# 	"url": "https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html",
# 	"datePublished": "2020-05-13T01:22:02+05:30",
# 	"dateModified": "2020-05-13T01:22:03+05:30",
# 	"articleBody": "In an address to the nation, Prime Minister Narendra Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be “totally different\" from the previous phases, the contours of which will be decided based on the suggestions given by states.",
# 	"alternativeHeadline": "Full text of PM Narendra Modi's speech on lockdown, stimulus package",
# 	"author": {
# 		"@type": "Person",
# 		"name": "Staff Writer"
# 	},
# 	"publisher": {
# 		"@type": "Organization",
# 		"name": "Livemint",
# 		"url": "https://www.livemint.com",
# 		"logo": {
# 			"@type": "ImageObject",
# 			"url": "https://images.livemint.com/mintlogo.jpg",
# 			"width": 600,
# 			"height": 60
# 		}
# 	},
# 	"image": {
# 		"@type": "ImageObject",
# 		"url": "https://images.livemint.com/img/2020/05/12/600x338/20200512277L_1589297156966_1589312829681.jpg",
#
# 		"height": 600 ,
# 		"width": 338
# 	},
# 	"isAccessibleForFree":"False",
#    "hasPart":{
#       "@type":"WebPageElement",
#       "isAccessibleForFree":"False",
#       "cssSelector":".paywall"
#    },
# 	"keywords": ["Narendra Modi","coronavirus","coronavirus pandemic","Narendra Modi speech on lockdown","Narendra Modi speech stimulus package","lockdown 4.0","Indian economy","coronavirus impact on Indian economy","Full text of PM Narendra Modi speech","Narendra Modi address to nation","text of PM Modi address to nation"]
# }
# </script><script type="application/ld+json">{ "@context" : "https://schema.org","@type": "WebPage","name": "Full text of PM Narendra Modi's speech on lockdown, stimulus package","description": "PM Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be 'totally different' from the previous phases.He also announced the long-awaited stimulus package of Rs20 trillion for businesses and workers to soften the devastating blow from the coronavirus lockdown" ,"speakable":{"@type":"SpeakableSpecification", "cssSelector":["Full text of PM Narendra Modi's speech on lockdown, stimulus package","PM Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be 'totally different' from the previous phases.He also announced the long-awaited stimulus package of Rs20 trillion for businesses and workers to soften the devastating blow from the coronavirus lockdown"]},"url":"https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html" }</script><script type="application/ld+json">{ "@context":"http://schema.org","@type":"SiteNavigationElement","name": ["News","Companies","Company Results","Start-ups","Mint 50 - Top Mutual Funds","Technology","Markets","Money","Mutual Funds","Lounge","Insurance","Opinion","Industry","Politics","Videos","Brand Post"],"url": [ "https://www.livemint.com/news","https://www.livemint.com/companies","https://www.livemint.com/companies/company-results","https://www.livemint.com/companies/start-ups","https://www.livemint.com/topic/mint-50-top-mutual-funds","https://www.livemint.com/technology","https://www.livemint.com/market","https://www.livemint.com/money","https://www.livemint.com/mutual-fund","https://www.livemint.com/mint-lounge","https://www.livemint.com/insurance","https://www.livemint.com/opinion","https://www.livemint.com/industry","https://www.livemint.com/politics","https://www.livemint.com/videos","https://www.livemint.com/brand-post"]}</script>
# <meta content="story" name="screen-name"/>
# <link href="/js/pwa/manifest_firebase.json" rel="manifest"/><script>
# var _dfp_site_name = 'Livemint';
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-TFD6PTW');</script><script async="async" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script> <script>(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function() { (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o), m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m) })(window,document,'script','https://www.google-analytics.com/analytics.js','ga'); ga('require', 'GTM-55G8RVF'); ga('create', 'UA-1466670-23', 'auto');	  if(document.cookie.indexOf('_gaexp=')!="-1") {
# var v = document.cookie.match('(^|;) ?' + "_gaexp" + '=([^;]*)(;|$)');
# if(v !=null){var lastDigit = v[2].slice(-1);
# dimensionValue = lastDigit;ga('set', 'dimension15', dimensionValue);}
# }
#  ga ('set', 'dimension1', "News");   ga ('set', 'dimension2', "13 May 2020, 01:11 AM IST");   ga ('set', 'dimension3', "Staff Writer");    ga ('set', 'dimension5', "11589312482447");  ga ('set', 'dimension6', "11 min read ");  ga('send', 'pageview');</script><script>var isMobile=false;var isTablet=false;var isDesktop=false; var isLargeDesktop=false; var WFClientTypeDef = {"large":"(min-width: 1024px)","small":"(max-width: 767px)","medium":"(min-width: 768px) and (max-width: 1023px)"}; for ( var type in WFClientTypeDef) { if (window.matchMedia(WFClientTypeDef[type]).matches) { switch (type) { case "large": isDesktop=true; break; case "medium": isTablet=true; break; case "small": isMobile=true; break;} break; }}
# function isDeviceEnabled(skipOnDeviceValue) {if(skipOnDeviceValue=="large" && isDesktop) {return true;}	if(skipOnDeviceValue=="medium" && isTablet){return true;} if(skipOnDeviceValue=="small" && isMobile){return true;}	return false; }
# var viewPortNumbers = 4;
# </script>
# <script>var googletag = googletag || {}; googletag.cmd = googletag.cmd || [];
# var googletagRHS = googletagRHS || {}; googletagRHS.cmd = googletagRHS.cmd || [];
# var pageTypeView = '';
# </script>
# <script>
# var storyFirAdSlotRefresh = [];
# var gptAdSlotReferesh = [];
# var gptAdSlotRefereshSlot = [];
# var adPreArray = [];
# var adCurrentArray = [];
# var adFullArray = [];
#
# var trackAdRendered = {
# 	_adCodediv : {},
# 	_adWebCast : {}
# }
# var firstStoryAdCounter = 1;
# var startCounter = 0;
# var adNumber = 0;
# var totalAds = 10;
#
#
# 	var adStoryArray = [];
#     var totalStoryAds = 9;
# 	var adslot0;
#     var adslot1;
#   googletag.cmd.push(function() {
#
#    if(isDeviceEnabled("small")) {
#        googletag.defineSlot('/1055314/LM_MF_WAP_AllPages_Masthead_Multisize', [320, 100], 'div-gpt-ad-1536154373501-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
# 	   googletag.defineSlot('/1055314/LM_MF_WAP_Story_Sticky_Multisize', [[300, 50], [320, 50]], 'div-gpt-ad-1563523997184-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
# 	   	   storyFirAdSlotRefresh[0] = googletag.defineSlot('/1055314/LM_MF_WAP_STORY_Top_Multisize', [[300, 250], [336, 280], 'fluid'], 'story-ads-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
# 	   storyFirAdSlotRefresh[1] = googletag.defineSlot('/1055314/LM_MF_WAP_STORY_Top1_Multisize', ['fluid', [300, 250], [336, 280]], 'story-ads-1').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
# 	   storyFirAdSlotRefresh[2] = googletag.defineSlot('/1055314/LM_MF_WAP_STORY_Top2_Multisize', [[300, 250], [336, 280], 'fluid'], 'story-ads-2').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
#
# }
#    if(isDeviceEnabled("large")) {
#     googletag.defineSlot('/1055314/LM_MF_DESK_AllPages_300x250_TOP', [300, 250], 'div-gpt-ad-1536154161359-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#     googletag.defineSlot('/1055314/LM_MF_DESK_AllPages_Masthead_Multisize', [[980, 80], [728, 90], [970, 90], [970, 250], [1290, 250]], 'div-gpt-ad-1536154100747-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#     storyFirAdSlotRefresh[0] = googletag.defineSlot('/1055314/LM_MF_Desk_STORY_Top_Multisize', [300, 250], 'story-ads-0').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
# 	storyFirAdSlotRefresh[1] = googletag.defineSlot('/1055314/LM_MF_Desk_STORY_Top1_Multisize', [300, 250], 'story-ads-1').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
# 	storyFirAdSlotRefresh[2] = googletag.defineSlot('/1055314/LM_MF_Desk_STORY_Top2_Multisize', [300, 250], 'story-ads-2').addService(googletag.pubads()).setCollapseEmptyDiv(true,true);
#
#     }
#
#     googletag.pubads().setTargeting("section", "News");
#     googletag.pubads().setTargeting("subsection", "India");
#     googletag.pubads().setTargeting("subsection", "11589312482447");
#
# var getQueryString = function ( field, url ) {
# 	var href = url ? url : window.location.href;
# 	var reg = new RegExp( '[?&]' + field + '=([^&#]*)', 'i' );
# 	var string = reg.exec(href);
# 	return string ? string[1] : null;
# };
#
#     var newsletterSource = getQueryString('utm_source');
#     if(newsletterSource != null && newsletterSource == "newsletter") {
#       console.log("Firing newletter.."+newsletterSource);
#       googletag.pubads().setTargeting("newsletter", "newsletter");
#     }
#
#    	googletag.pubads().enableSingleRequest();
#    	googletag.pubads().disableInitialLoad();
#     googletag.enableServices();
#     googletag.pubads().addEventListener('slotRenderEnded', function(event) {
# 			    if(event.slot.getSlotElementId() === 'div-gpt-ad-1536154373501-0' && event.isEmpty){
# 				    document.getElementById("pushDownAd").style.display="none";
# 				}
# 			});
#   });
# </script>
# <script>
# if (isDeviceEnabled("large")) {
# 	googletag.cmd.push(function() {
# 			var REFRESH_KEY = 'refresh';
#   			var REFRESH_VALUE = 'true';
# 		    googletag.defineSlot('/1055314/LM_MF_DESK_AllPages_300x250_Middle', [[300, 250], [300, 600]], 'div-gpt-ad-1536154273332-0').setTargeting(REFRESH_KEY, REFRESH_VALUE).addService(googletag.pubads())
# 		    var SECONDS_TO_WAIT_AFTER_VIEWABILITY = 30;
# 		    googletag.pubads().addEventListener('impressionViewable', function(event) {
# 			    var slot = event.slot;
# 			    if (slot.getTargeting(REFRESH_KEY).indexOf(REFRESH_VALUE) > -1) {
# 			      setTimeout(function() {
# 			        googletag.pubads().refresh([slot]);
# 			      }, SECONDS_TO_WAIT_AFTER_VIEWABILITY * 1000);
# 			    }
# 			  });
# 			  googletag.pubads().enableSingleRequest();
# 		    googletag.pubads().disableInitialLoad();
# 		    googletag.enableServices();
#
#   });
#   }
# </script><script> var _comscore = _comscore || []; _comscore.push({ c1: "2", c2: "6035286" }); (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el);  })(); </script><noscript><img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035286&amp;cv=2.0&amp;cj=1"/></noscript>
# <script>function comScore() {
# /*
# var _comscore = _comscore || []; _comscore.push({ c1: "2", c2: "6035286" }); (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el);  })();
# */
#
# var sLash = "/";
# var qPara = "?";
# var responseUrl = "customResponse.json";
#
# self.COMSCORE && COMSCORE.beacon({c1: "2", c2: "6035286"});
# var randomNumber = Math.floor((Math.random() * 9999999) + 1);
# var xhttp = new XMLHttpRequest();
#
# var apiURL = sLash+"js"+sLash+responseUrl+qPara+"q="+randomNumber;
# xhttp.open("GET", apiURL,  true);
# xhttp.send();
# xhttp.onreadystatechange = function() {
# 	 if (xhttp.readyState == 4 && xhttp.status == 200) {
#
# 	 }
# }
# }</script><script type="text/javascript">
# var _sf_async_config = _sf_async_config || {};
# _sf_async_config.uid = 63228;
# _sf_async_config.domain = "livemint.com";
# _sf_async_config.flickerControl = false;
# _sf_async_config.useCanonical = true;
# var _sf_startpt = (new Date()).getTime();
# </script><script async="" src="//static.chartbeat.com/js/chartbeat_mab.js"></script><script> if(window.location.hostname.toString() == "localhost" || window.location.hostname.toString() == "staging.livemint.com"  || window.location.hostname.toString() == "qa.livemint.com"  || window.location.hostname.toString() == "stg-subs.livemint.com") {
# (function(p, l, o, w, i, n, g) { if (!p[i]) { p.GlobalSnowplowNamespace = p.GlobalSnowplowNamespace || []; p.GlobalSnowplowNamespace.push(i); p[i] = function() { (p[i].q = p[i].q || []).push(arguments); }; p[i].q = p[i].q || []; n = l.createElement(o); g = l.getElementsByTagName(o)[0]; n.async = 1; n.src = w; g.parentNode.insertBefore(n, g); p['product_id'] = 'lm'; p['platoform'] = 'web';  } }(window, document, 'script', "https://analytics.dev.htmedia.in/app/collector.js", 'snowplow'));
# }
# /*else if(window.location.hostname.toString() == "pre-prod.livemint.com") {
# (function(p, l, o, w, i, n, g) { if (!p[i]) { p.GlobalSnowplowNamespace = p.GlobalSnowplowNamespace || []; p.GlobalSnowplowNamespace.push(i); p[i] = function() { (p[i].q = p[i].q || []).push(arguments); }; p[i].q = p[i].q || []; n = l.createElement(o); g = l.getElementsByTagName(o)[0]; n.async = 1; n.src = w; g.parentNode.insertBefore(n, g); p['product_id'] = 'lm'; p['platoform'] = 'web';  } }(window, document, 'script', "https://analytics.dev.htmedia.in/app/collector.js", 'snowplow'));
# } */
# else {
# (function(p, l, o, w, i, n, g) { if (!p[i]) { p.GlobalSnowplowNamespace = p.GlobalSnowplowNamespace || []; p.GlobalSnowplowNamespace.push(i); p[i] = function() { (p[i].q = p[i].q || []).push(arguments); }; p[i].q = p[i].q || []; n = l.createElement(o); g = l.getElementsByTagName(o)[0]; n.async = 1; n.src = w; g.parentNode.insertBefore(n, g); p['product_id'] = 'lm'; p['platoform'] = 'web';  } }(window, document, 'script', "https://analytics.htmedia.in/analytics-js/dap.js", 'snowplow'));
# }
#
#
# 	 var snowplowSection = "News";
# </script><script id="_webengage_script_tag" type="text/javascript">
# if(window.location.hostname.toString() == "staging.livemint.com" || window.location.hostname.toString() == "preprod.livemint.com" || window.location.hostname.toString() == "qa.livemint.com" || window.location.hostname.toString() == "stg-subs.livemint.com") {
# var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
# arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://ssl.widgets.webengage.com":"http://cdn.widgets.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");
# webengage.init("~c2ab3023");
# } else if(window.location.hostname.toString() == "pre-prod.livemint.com") {
# var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
# arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://ssl.widgets.webengage.com":"http://cdn.widgets.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");webengage.init("~134105974");
# } else {
# var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
# arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://ssl.widgets.webengage.com":"http://cdn.widgets.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");webengage.init("~134105974");
# }
# </script><script>
# function getCookieWe(name) {
#     var nameEQ = name + "=";
#     var ca = document.cookie.split(";");
#     for (var i = 0; i < ca.length; i++) {
#         var c = ca[i];
#         while (c.charAt(0) == " ") {
#             c = c.substring(1, c.length);
#         }
#         if (c.indexOf(nameEQ) == 0) {
#             return c.substring(nameEQ.length, c.length);
#         }
#     }
#     return null;
# }
# function we() {
# //var url = new URL(window.location.href);
# if(window.location.href.indexOf(".html") != -1) {
#  var viewData = {};
#  	var cookie_token = getCookieWe("token");
# 	var user_name = getCookieWe("name");
# 	viewData["user state"] = "Anonymous"
# 	if(cookie_token && user_name){
# 		viewData["user state"] = "Signed In"
# 	}
#
#                 viewData["section"] = "News";
#            viewData["subsection"] = "India";
# 		    viewData["publishedDate"] = "13 May 2020";
# 		      viewData["publishedTime"] = "01:22 AM IST";
# 		     viewData["author"] = "Staff Writer";
# 		     viewData["storyType"] = "story";
# 		      viewData["timeToRead"] = parseInt("11");
#              viewData["articleDesk"] ="DIGITAL";
#      console.log(viewData);
#
#      webengage.track("ArticleRead",  viewData);
#
#   window.onbeforeunload = function (event) {
#
#      var viewData = {};
#            viewData["section"] = "News";
#            viewData["subsection"] = "India";
# 		     viewData["storyType"] = "story";
#               console.log(viewData);
#            	webengage.track("BrowserClose", viewData);
#
# };
#
# } else {
# }
#
#
#
# }
# we();
# </script>
# <script>
# function loadVignetteGoogleScript(){
#        var ScriptId = "_google_vignette";
#        var Script = document.getElementById(ScriptId);
#        if (Script === null) {
#            var tag = document.createElement("script");
#            var firstScript = document.getElementsByTagName("script")[0];
#            var srcUrl = "https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js";
#            tag.src = srcUrl;
#            tag.setAttribute("data-ad-client", "ca-pub-7491439242520231");
#            tag.async = true;
#            tag.id = ScriptId;
#            firstScript.parentNode.insertBefore(tag, firstScript);
#        }
#    }
# if(isDeviceEnabled("small")) {
# 	loadVignetteGoogleScript();
# }
# </script>
# <script> window.twttr = (function (d,s,id) { var t, js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js=d.createElement(s); js.id=id; js.async=true; js.src="https://platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js, fjs); return window.twttr || (t = { _e: [], ready: function(f){ t._e.push(f) } }); }(document, "script", "twitter-wjs")); </script>
# <script>var interval;function getCurrentTime(){var xhttp=new XMLHttpRequest;xhttp.open("GET","/currenttimestamp",true);xhttp.send(null);xhttp.onreadystatechange=function(){if(xhttp.readyState==4&&xhttp.status==200){r=xhttp.response;var date=new Date(r);document.getElementById("currentDate").setAttribute("currentTimeStamp",Math.round(r/1E3));getHeaderTime();topNavSelection()}}}
# function getCurrentWeather(n){var xhttp=new XMLHttpRequest;xhttp.open("GET","/weather/"+n,true);xhttp.send(null);xhttp.onreadystatechange=function(){if(xhttp.readyState==4&&xhttp.status==200)document.getElementById("showWeather").innerHTML=xhttp.response}}function showTime(){[].forEach.call(document.querySelectorAll('*[id^="tBox_"]'),function(el){});[].forEach.call(document.querySelectorAll('*[id^="tBoxCollection_"]'),function(el){getTimeDifference(el.getAttribute("data-updatedtime"),el.id)})}
# function basicSearch(e,inputId,str){var searchText=document.getElementById(inputId).value;var regex=/^[a-zA-Z0-9-,.@&;:'"$%+ ]+$/;if(regex.test(document.getElementById(inputId).value)==false||document.getElementById(inputId).value.trim()==""){var inputVal=document.getElementById(inputId).value;document.getElementById(inputId).value=inputVal.substr(0,inputVal.length-1)}if(searchText.length>=3){var xhttp=new XMLHttpRequest;apiURL="/autosuggest"+"/"+searchText;xhttp.open("GET",apiURL,true);xhttp.send();xhttp.onreadystatechange=function(){if(xhttp.readyState==4&&xhttp.status==200){var response=replaceAll(xhttp.response,"getAuto(","getAuto('"+inputId+"','"+str+"',");document.getElementById("ajax_response_"+str).innerHTML=response;if(xhttp.response==""||xhttp.response==null)document.getElementById("ajax_response_"+str).style.display="none";else document.getElementById("ajax_response_"+str).style.display="block";showTime()}else console.log("",xhttp.status)}}else document.getElementById("ajax_response_"+str).style.display="none";if(e!="1"){if(e.keyCode==13){var tb=document.getElementById(inputId);if(tb.value==""||tb.value==null){alert("Please enter the keyword");tb.focus();return false}else{console.log(encodeURIComponent(tb.value));var sp="/Search/Link/Keyword/"+encodeURIComponent(tb.value.replace("%","").replace(" ","-"));top.location.href=sp.replace(/%20/g,"-");return false}}}else{var tb=document.getElementById(inputId);if(tb.value==""||tb.value==null||tb.value=="Search"){alert("Please enter the keyword");tb.focus();return false}else{console.log(encodeURIComponent(tb.value));var sp="/Search/Link/Keyword/"+encodeURIComponent(tb.value.replace("%","").replace(" ","-"));location.href=sp.replace(/%20/g,"-")}}}function toTimeStamp(dateTime){var dateTimeSplit=dateTime.split("T");var dateArray=dateTimeSplit[0].split("-");var timeArray=dateTimeSplit[1].split("+");var timeArray1=timeArray[0].split(":");var datum=new Date(Date.UTC(dateArray[0],dateArray[1]-1,dateArray[2],timeArray1[0],timeArray1[1],timeArray1[2]));return datum.getTime()/1e3-parseInt("19800")}</script>
# <style>.fade {animation-name: fade; animation-duration: 2s;} @keyframes fade { from { opacity: 0; } to { opacity: 1; } }</style>
# <script id="_webengage_script_tag" type="text/javascript">
# if(window.location.hostname.toString() == "staging.livemint.com" || window.location.hostname.toString() == "preprod.livemint.com" || window.location.hostname.toString() == "qa.livemint.com" || window.location.hostname.toString() == "stg-subs.livemint.com") {
# var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
# arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://ssl.widgets.webengage.com":"http://cdn.widgets.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");
# webengage.init("~c2ab3023");
# } else if(window.location.hostname.toString() == "pre-prod.livemint.com") {
# var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
# arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://ssl.widgets.webengage.com":"http://cdn.widgets.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");webengage.init("~134105974");
# } else {
# var webengage;!function(w,e,b,n,g){function o(e,t){e[t[t.length-1]]=function(){r.__queue.push([t.join("."),
# arguments])}}var i,s,r=w[b],z=" ",l="init options track screen onReady".split(z),a="feedback survey notification".split(z),c="options render clear abort".split(z),p="Open Close Submit Complete View Click".split(z),u="identify login logout setAttribute".split(z);if(!r||!r.__v){for(w[b]=r={__queue:[],__v:"6.0",user:{}},i=0;i < l.length;i++)o(r,[l[i]]);for(i=0;i < a.length;i++){for(r[a[i]]={},s=0;s < c.length;s++)o(r[a[i]],[a[i],c[s]]);for(s=0;s < p.length;s++)o(r[a[i]],[a[i],"on"+p[s]])}for(i=0;i < u.length;i++)o(r.user,["user",u[i]]);setTimeout(function(){var f=e.createElement("script"),d=e.getElementById("_webengage_script_tag");f.type="text/javascript",f.async=!0,f.src=("https:"==e.location.protocol?"https://ssl.widgets.webengage.com":"http://cdn.widgets.webengage.com")+"/js/webengage-min-v-6.0.js",d.parentNode.insertBefore(f,d)})}}(window,document,"webengage");webengage.init("~134105974");
# }
# </script><script type="text/javascript">
# ;window.NREUM||(NREUM={});NREUM.init={privacy:{cookies_enabled:true}};
# window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var i=n[t]={exports:{}};e[t][0].call(i.exports,function(n){var i=e[t][1][n];return r(i||n)},i,i.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<t.length;i++)r(t[i]);return r}({1:[function(e,n,t){function r(){}function i(e,n,t){return function(){return o(e,[u.now()].concat(f(arguments)),n?null:this,t),n?void 0:this}}var o=e("handle"),a=e(4),f=e(5),c=e("ee").get("tracer"),u=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",d=l+"ixn-";a(p,function(e,n){s[n]=i(l+n,!0,"api")}),s.addPageAction=i(l+"addPageAction",!0),s.setCurrentRouteName=i(l+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,i="function"==typeof n;return o(d+"tracer",[u.now(),e,t],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],t),i)try{return n.apply(this,arguments)}catch(e){throw c.emit("fn-err",[arguments,this,e],t),e}finally{c.emit("fn-end",[u.now()],t)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=i(d+n)}),newrelic.noticeError=function(e,n){"string"==typeof e&&(e=new Error(e)),o("err",[e,u.now(),!1,n])}},{}],2:[function(e,n,t){function r(e,n){var t=e.getEntries();t.forEach(function(e){"first-paint"===e.name?c("timing",["fp",Math.floor(e.startTime)]):"first-contentful-paint"===e.name&&c("timing",["fcp",Math.floor(e.startTime)])})}function i(e,n){var t=e.getEntries();t.length>0&&c("lcp",[t[t.length-1]])}function o(e){if(e instanceof s&&!l){var n,t=Math.round(e.timeStamp);n=t>1e12?Date.now()-t:u.now()-t,l=!0,c("timing",["fi",t,{type:e.type,fid:n}])}}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var a,f,c=e("handle"),u=e("loader"),s=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){a=new PerformanceObserver(r),f=new PerformanceObserver(i);try{a.observe({entryTypes:["paint"]}),f.observe({entryTypes:["largest-contentful-paint"]})}catch(p){}}if("addEventListener"in document){var l=!1,d=["click","keydown","mousedown","pointerdown","touchstart"];d.forEach(function(e){document.addEventListener(e,o,!1)})}}},{}],3:[function(e,n,t){function r(e,n){if(!i)return!1;if(e!==i)return!1;if(!n)return!0;if(!o)return!1;for(var t=o.split("."),r=n.split("."),a=0;a<r.length;a++)if(r[a]!==t[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}n.exports={agent:i,version:o,match:r}},{}],4:[function(e,n,t){function r(e,n){var t=[],r="",o=0;for(r in e)i.call(e,r)&&(t[o]=n(r,e[r]),o+=1);return t}var i=Object.prototype.hasOwnProperty;n.exports=r},{}],5:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,i=t-n||0,o=Array(i<0?0:i);++r<i;)o[r]=e[n+r];return o}n.exports=r},{}],6:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function i(e){function n(e){return e&&e instanceof r?e:e?c(e,f,o):o()}function t(t,r,i,o){if(!l.aborted||o){e&&e(t,r,i);for(var a=n(i),f=v(t),c=f.length,u=0;u<c;u++)f[u].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function d(e,n){h[e]=v(e).concat(n)}function m(e,n){var t=h[e];if(t)for(var r=0;r<t.length;r++)t[r]===n&&t.splice(r,1)}function v(e){return h[e]||[]}function g(e){return p[e]=p[e]||i(t)}function w(e,n){u(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var h={},y={},b={on:d,addEventListener:d,removeEventListener:m,emit:t,get:g,listene ...
# ;NREUM.loader_config={accountID:"2747945",trustKey:"586118",agentID:"556728437",licenseKey:"NRJS-777eaf04e06b2329598",applicationID:"556728437"}
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"NRJS-777eaf04e06b2329598",applicationID:"556728437",sa:1}
# </script></head>
# <body class="" id="search"><!-- Begin BlueKai Tag -->
# <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0"></iframe>
# <script src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript"></script>
# <script type="text/javascript">
# bk_doJSTag(85272, 1);
# </script>
# <!-- End BlueKai Tag --><style>.notFound{ background:url(/images/static/error-404-new.svg) 0 0 no-repeat; box-sizing: border-box; padding:240px 45px 0; font-size:13px; color: #424242; font-family: 'Lato Regular',sans-serif; font-weight:400; margin:0 auto; width:253px; height:312px; text-align:center;}@font-face{font-family:'PT Serif Regular';src:url("/fonts/PT_Serif-Web-Regular.woff2") format("woff");font-weight:400;font-style:normal}@font-face{font-family:'PT Serif Bold';src:url("/fonts/PT_Serif-Web-Bold.woff2") format("woff");font-weight:700;font-style:normal}@font-face{font-family:'Lato Regular';src:url("/fonts/Lato-Regular.woff2") format("woff");font-weight:400;font-style:normal}@font-face{font-family:'Lato Bold';src:url("/fonts/Lato-Bold.woff2") format("woff");font-weight:700;font-style:normal}@font-face{font-family:'Lato Black';src:url("/fonts/Lato-Black.woff2") format("woff");font-weight:900;font-style:normal}.dnone{display:none !important}span.webrupee,span.WEBRUPEE{font-family:none}*{-webkit-tap-highlight-color:rgba(0,0,0,0);-webkit-backface-visibility:hidden;padding:0;margin:0;list-style-type:none;outline:none;text-decoration:none;word-wrap:break-word}body{background:#f6f6f6;overflow-x:hidden}.clearfix:after{content:".";clear:both;display:block;height:0;visibility:hidden}.clear{clear:both}.overflowHidden{overflow:hidden}img{max-width:100%}.fl{float:left}.fr{float:right}.marZero{margin:0 !important}.alignC{text-align:center}.container{width:1100px;margin:0 auto}.iconSprite{background-image:url(/images/icon-sprite.svg);width:18px;height:20px;float:left;margin-left:19px;background-repeat:no-repeat}.icoBookmark2.delethstry{background-image:url(/images/static/delete_v2.svg);width:18px;height:20px;float:left;margin-left:24px;background-repeat:no-repeat;display:inline-block;background-position:0 0}.bkmrmsg{position:fixed;bottom:40px;z-index:10;text-align:center;width:100%;left:-4%}.bkmrmsg span{border-radius:20px;padding:10px 35px;color:#fff;background:#969696;font-size:14px;font-family:'Lato bold',sans-serif}a{color:#212121;text-decoration:none}a:hover{color:#757575}.bodyHolder{padding-top:20px;position:relative}.leftSec{width:210px;margin-right:20px;float:left;position:-webkit-sticky;position:sticky;top:85px}.rightSec{width:300px;margin-left:20px;float:right}.mainSec{width:550px;float:left;min-height:1000px}.vSpace{margin-top:10px}.adHolder{overflow:hidden}.adHolderAfterLoad{padding:20px 20px 15px;background:#fff;margin:10px auto 10px;text-align:center;display:block;overflow:hidden} .adHolderStory{padding:20px 10px 10px;background:url(/images/advertisement.svg) no-repeat center 6px #fff; border:1px solid #e0e0e0;margin:10px auto 10px;text-align:center;display:block;overflow:hidden}.storyadHolderAfterLoad{width:300px !important; box-sizing:unset}.adHolder div{margin:0 auto !important;}a.newStories{border-radius:13px;background-image:linear-gradient(to right, #7aacff, #2486f9);box-shadow:0 2px 13px 0 rgba(0, 0, 0, 0.5);color:#fff;font-size:14px;font-family:'Lato Regular',sans-serif;font-weight:400;position:fixed;width:102px;left:50%;margin:0 0 0 -71px;text-align:center;padding:5px 10px;z-index:99;top:100px;animation:newStories 1s forwards 3s ease-in;opacity:0}@keyframes newStories{0%{transform:translateY(-100%);opacity:0}100%{transform:translateY(0);opacity:1}}.ptb20{padding-top:20px;padding-bottom:20px}.stickyAd{width:300px;height:250px;color:#fff;display:block;position:-webkit-sticky;position:sticky;top:70px}header{-webkit-transition:all 0.4s ease;transition:all 0.4s ease;position:-webkit-sticky;position:sticky;top:0px;background:#fff;padding:20px 0;box-shadow:0 2px 20px 0 rgba(0,0,0,0.13);width:100%;text-align:center;z-index:9}header.sticky{-webkit-transition:all 0.4s ease;transition:all 0.4s ease;padding:10px 0}header.sticky .headerDate{display:none}header.sticky a.logo{width:150px;margin-left:-129px}header.sticky .btnSection{margin:8px 0 5px 10px}header.sticky .headerIcon{padding-top:15px}a.logo{-webkit-transition:all  ...
# .pb10{ padding-bottom:16px !important;}
# .cardHolder.cardEmbed{position:relative;}
# .cardHolder.cardEmbed .embed{ padding:0;}
# .cardHolder.cardEmbed .externalLink{ position:absolute; top:0; left:0; width:100%; height:100%;}
# .cardHolder.cardEmbed h1{padding: 0 0 16px;}
# .cardHolder.cardEmbed .cardheading.breakingNews{ margin:0 0 16px;}
# header .budgetAdd{width:100%; height:75px; opacity:1; margin:10px 0; transition: all 0.1s ease;}
# header.sticky .budgetAdd{ opacity:0; height:0; margin-top:0; transition: all 0.1s ease; display:none;}
# .adHolderStory.storyadHolderAfterLoad.lastAdStory{ float:left; margin:0 0 0 20px;}
# .signUpcardStory{width:146px; font-size:14px; float:right; display:inline-block;  margin:0 20px; border: solid 1px #e0e0e0; padding:10px 10px 3px; text-align:center; color: #151515; font-weight:400;font-family:'Lato regular',sans-serif;}
# .cardHolder.open .signUpcardStory h2, .cardHolderAd .signUpcardStory h2{font-size: 14px;    line-height: 16px;    padding: 8px 0; margin-bottom:0px;   font-weight: 700;    font-family: 'Lato Bold',sans-serif;}
# .cardHolder.open .signUpcardStory .cardContent a, .cardHolderAd .signUpcardStory .cardContent a {    background: #f7931e;    font-family: 'Lato Bold',sans-serif;   color: #ffffff;    font-size: 12px;    font-weight: 700;    display: inline-block;    padding: 10px 8px;    margin: 10px 0;    border-radius: 4px;}
# .cardHolder.open .signUpcardStory .cardGraphic{ margin:0 0 5px 20px;}
# .cardHolderAd {padding:20px;}
# #lastAd{ margin-bottom:20px;}
# .adMweb{display:none;}
# .desktopAd.adSpace > div, .desktopAd.adSpace > div > div, .desktopAd.adSpace > div >div > div {margin:0 auto;}
# div.icosubscription{background:url(/images/ico-subscription.svg) no-repeat 0 0; margin-right:10px; width:20px; height:20px;}
# div.icosmartcast{background:url(/images/icon-smartCast.svg) no-repeat 0 -2px; margin-right:10px; width:20px; height:20px;}
#
# .wsj{ padding:15px 0 15px 20px !important; margin-bottom:10px; border-bottom:1px solid #f6f6f6; width:240px;}
# .wsj2{ padding:0 0 17px 10px; margin-bottom:20px; border-bottom:1px dashed #bdbdbd; width:96%; display:block;}
# .cardHolder .wsjStory{ padding-left:20px; margin:16px 0 0; display:block;}
# .cardHolder.open .wsjStory{ padding-left:20px; margin:5px 0 0; display:block;}
# .wsjcollection{    padding-left: 10px;    margin: 16px 0 0;    display: block;}
# .cardHolder  .listing .wsjStory, .cardHolder.open  .listing .wsjStory{ padding:0; margin: 0 0 5px; display:block;}
# .cardHolder  .listing2 .wsjStory, .cardHolder.open  .listing2 .wsjStory{padding:0}
# .userSignin{background:url(/images/user.svg) no-repeat 0 2px; font-size:16px; padding-left:26px; height:20px;     font-family: 'Lato bold',sans-serif; font-weight:700; float:right; margin-top:-5px;}
# .ad510{padding: 20px; width:100%; box-sizing:border-box; text-align:center;   background: url(/images/advertisement.svg) no-repeat center 6px #fff;    border: 1px solid #e0e0e0;    margin: 10px auto 10px;    text-align: center;    display: block;    overflow: hidden;}
# .ad510 .iframe{margin:0 auto;}
# .monica{position:absolute; top:0; right:0; height:58px;}
# .monica span{font-size:12px; font-family: 'Lato Regular',sans-serif; font-weight:400; color:#757575; line-height:58px;}
# .monica .sponsor{float:right; margin-left:10px;}
# .epaperPromo{margin-bottom:20px;}
# .epaperPromo a{ color:#f7941e !important; text-decoration:underline;}
# .epaperPromo a:hover{ text-decoration:none;}
# .epaperPromo span{display:block; margin-bottom:16px;}
#
# body.imgZoom{overflow:hidden;}body.imgZoom #header,body.imgZoom .lastAd, body.imgZoom #header a.logo,body.imgZoom section.cardHolder.open a.btnClose,body.imgZoom .leftSec{position:static;}.storyEmbedImg {  border-radius: 5px;  cursor: zoom-in;  transition: 0.3s;}.storyEmbedImg:hover {opacity: 0.7;}.modal {  display: none; position: fixed;  z-index: 1;  padding-top: 100px;  left: 0;  top: 0;  width: 100%;  height: 100%;  overflow: auto;  background-color: rgb(0,0,0);  background-color: rgba(0,0,0,0.9);}.modal-content {  margin: auto;  display: block;  width: 80%;  max-width: 700px;}#caption {  margin: auto;  display: block;  width: 80%;  max-width: 700px;  text-align: center;  color: #ccc;  padding: 10px 0;  height: 150px;}.modal-content, #caption {  -webkit-animation-name: zoom;  -webkit-animation-duration: 0.6s;  animation-name: zoom;  animation-duration: 0.6s;}@-webkit-keyframes zoom {  from {-webkit-transform:scale(0)}  to {-webkit-transform:scale(1)}}@keyframes zoom {  from {transform:scale(0)}  to {transform:scale(1)}}.close {  position: absolute;  top: 15px;  right: 35px;  color: #f1f1f1;  font-size: 40px;  font-weight: bold;  transition: 0.3s;}.close:hover,.close:focus {  color: #bbb;  text-decoration: none;  cursor: pointer;}@media only screen and (max-width: 700px){  .modal-content {    width: 100%;  }}
# ...
# 50%{transform:rotateY(0deg)}
# 90%{transform:rotateY(0deg)}
# 100%{transform:rotateY(-360deg)}
# }
# @keyframes mymove{40%{transform:rotateY(0deg)}
# 50%{transform:rotateY(180deg)}
# 90%{transform:rotateY(180deg)}
# 100%{transform:rotateY(0deg)}
# }
# @keyframes mymoveback{40%{transform:rotateY(-180deg)}
# 50%{transform:rotateY(0deg)}
# 90%{transform:rotateY(0deg)}
# 100%{transform:rotateY(-180deg)}
# }
#
# .crossbutton {
#    border: 1px solid #ff0808;
#    transform: rotate(45deg);
#    width: 21px;
#    height: 21px;
#    margin: -12px 0 0 -12px;
#    float: left;
#    border-radius: 50%;
#    background: #FFF;
#    box-sizing:border-box;
#    position: absolute;
#    cursor: pointer;
#    z-index:10;
# }
#
# .crossbutton:after {
#    position: absolute;
#    content: '';
#    top: 9px;
#    left: 5px;
#    width: 9px;
#    height: 1px;
#    background: #ff0808;
# }
#
# .crossbutton:before {
#    position: absolute;
#    content: '';
#    top: 5px;
#    left: 9px;
#    height: 9px;
#    width: 1px;
#    background: #ff0808;
# }
#
#     </style>
# <div class="clearfix" id="corona-div" style="display:none;">
# <div class="eclt-rsttble" id="eclt-rsttbleflip" style="display:none;">
# <div class="shadow" id="eclt-rsttbleflipdash">
# </div>
# </div>
# </div>
# <script>
# function getCookieCorona(name) {var nameEQ = name + "="; var ca = document.cookie.split(";"); for (var i = 0; i < ca.length; i++) {var c = ca[i]; while (c.charAt(0) == " ") {c = c.substring(1, c.length); } if (c.indexOf(nameEQ) == 0) {return c.substring(nameEQ.length, c.length); } } return null; }
# function setCookieCorona(cname, cvalue, exdays) {var d = new Date; d.setTime(d.getTime() + exdays * 24 * 60 * 60 * 1000); var expires = "expires=" + d.toUTCString(); document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/"; }
#     var corona=getCookieCorona("corona");
# if(corona){
# 	document.getElementById("corona-div").style.display = "none";
# } else {
# document.getElementById("corona-div").style.display = "block";
#   getHTTPRequestCorona("https://www.livemint.com/feed-elections/5m/coronavirus.json", "eclt-rsttbleflipdash", true);
# }
# function getFirstKey(obj) {
#     for (key in obj) {
#         return key;
#     }
# }
#
# function hideCross() {
# document.getElementById("corona-div").style.display = "none";
#   if(typeof setCookieCorona!=='undefined'){
# 	setCookie("corona","true",1);
#    }
# }
# function getHTTPRequestCorona(url, id, json) {
#     var xhttp = new XMLHttpRequest;
#     if (json == true) {
#         xhttp.responseType = "json";
#     }
#     xhttp.open("GET", url, true);
#     xhttp.send();
#     xhttp.onreadystatechange = function() {
#     if (xhttp.readyState == 4 && xhttp.status == 200) {
#          var objResponse = xhttp.response;
#          var flipText = "";
#          if(objResponse.data_eng!=null && objResponse.data_eng!==undefined && objResponse.data_eng!=''){
#          		[].forEach.call(objResponse.data_eng, function(el, i){
#          		flipText = flipText + '<div class="widget-inner loadable" id="election'+i+'"><div class="crossbutton" onClick = "hideCross();"></div><a class="fll-covrge" href="/topic/coronavirus"><span>COVID-19</span><ul id="t'+(i+1)+'"><li><span>'+getFirstKey(el)+'</span><span>'+el[getFirstKey(el)]+'</span></li></ul></a></div>';
#           		 });
#
#          		}
#          		document.getElementById("eclt-rsttbleflip").style.display = "block";
# 			    document.getElementById('eclt-rsttbleflipdash').innerHTML = flipText;
#       }
#     }
#  }
#     </script><style> .popup.p20{ padding: 20px !important} .popup.p20 p{ margin-bottom: 0 !important} .popup.p20 h3{ font-size:30px !important; font-weight:600 !important; font-family: 'Lato Bold',sans-serif; margin:5px 0 10px 0;} @media (max-width: 599px) {.popup.p20 h3{ font-size:22px !important;} } </style><div class="popupsection" id="subReminderPopUp" style="display: none;"><div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup p20"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('subReminderPopUp').style.display='none';" style="cursor:pointer;"></a><img alt="" class="lozad" data-src="/images/subscribe-for-free.svg" src="/images/static/1x1_img.gif"/><h3>Congratulations!</h3><p>You are now subscribed to our newsletters. In case you can’t find any email from our side, please check the spam folder.</p></div></div></div></div>
# <script>
#
#
# function callTab() { [].forEach.call(document.querySelectorAll('*[id^="defaultOpen_"]'), function(el) { document.getElementById(el.id).click(); }); }
# callTab();
# function openCityElec(evt, cityName,j) { var i, tabcontent, tablinks; tabcontent = document.getElementsByClassName("tabcontent_"+j); for (i = 0; i < tabcontent.length; i++) { tabcontent[i].style.display = "none"; } tablinks = document.getElementsByClassName("tablinks_"+j); for (i = 0; i < tablinks.length; i++) { tablinks[i].className = tablinks[i].className.replace(" active", ""); } document.getElementById(cityName).style.display = "block"; evt.currentTarget.className += " active"; }
#  </script>
# <script src="https://players.brightcove.net/5857818229001/default_default/index.min.js"></script>
# <script src="/js/localWorker.js?v2.0.5"></script>
# <script> var localWorker = new LocalWorker(); localWorker.init();</script>
# <script src="/__js/staticProperties_v1,inview_loz_slider,custom_v16,displayAdsNew_v20,onScroll_v25,podcastscript,lm_brightcove,lm_subscription_v4,getBody_v12.js?v1.0.280"></script>
# <script>lozad('.lozad', { load: function(el) { el.src = el.dataset.src; el.onload = function() { el.classList.add('fade')}}}).observe()</script>
# <script type="text/javascript">
# (function() {
#         /** CONFIGURATION START **/
#         var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#
# 							     _sf_async_config.sections = 'News'; //CHANGE THIS TO YOUR SECTION NAME(s)
# 										_sf_async_config.authors = 'Staff Writer';
#
#
#         function loadChartbeat() {
#             var e = document.createElement('script');
#             var n = document.getElementsByTagName('script')[0];
#             e.type = 'text/javascript';
#             e.async = true;
#             e.src = '//static.chartbeat.com/js/chartbeat.js';
#             n.parentNode.insertBefore(e, n);
#         }
#         loadChartbeat();
#      })();
#
#
#
# </script>
# <script>
# if(typeof pageName != undefined && pageName == 'notifications'){
#  document.getElementById("noTCounter").style.display = "none"; notificationInside();
# 	//document.getElementById("noTCounter").innerHTML = notiCounter;
# }
# </script>
# <link href="https://players.brightcove.net/videojs-pip/1/videojs-pip.css" rel="stylesheet"/><script src="https://players.brightcove.net/videojs-pip/1/videojs-pip.min.js"></script>
# <script src="/js/marketconfig.js?v3.0.1"></script>
# <div class="adMweb"><div id="div-gpt-ad-1563523997184-0"> <script> googletag.cmd.push(function() { googletag.display('div-gpt-ad-1563523997184-0'); }); </script> </div></div>
# <div class="modal" id="myModalZoomBox"><span class="close">×</span><img class="modal-content" id="img01"/><div id="caption"></div></div>
# <script async="true" src="/js/mint_script.js?v1.0.1"></script>
# <script async="true" src="/service-worker.js"></script>
# <script src="https://www.google.com/recaptcha/api.js?render=explicit"></script>
# <style>
# .myAccount {height: 100%;  width: 0;  position: fixed;  z-index: 10;  top: 0;  right: 0;  background-color: #fff;  overflow-x: hidden;  transition: 0.5s;}
# .myAccount .closebtn {  position: absolute;  top: 0;  right: 25px;  font-size: 36px; color:#fff;}
# .Userbgoverlay{ background:#000; opacity:.33; display:none; position:fixed; width:100%; height:100%; top:0; left:0; z-index:9;}
# .myAccount .userDetails{ background:#f7941e; padding:30px; text-align:center; color:#fff;}
# .myAccount .userDetails .initial{ width:98px; height:98px; text-align:center; color:#f79220;font-family: 'Lato Regular',sans-serif; font-weight:400; background:#fff; border-radius:50%; font-size:50px; line-height:98px; margin:0 auto 30px;}
# .myAccount .userDetails .uName{font-family: 'Lato bold',sans-serif; font-weight:700; color:#fff; font-size:16px; margin-bottom:16px;}
# .myAccount .userDetails .uName strong{display:block; font-size:20px;}
# .myAccount .userDetails a{display:inline-block; font-family: 'Lato bold',sans-serif; font-weight:700; color:#fff; font-size:16px; border:1px solid #fff; padding:8px 42px; border-radius:30px;}
# .myAccount .planSec{font-family: 'Lato Regular',sans-serif; font-weight:400; font-size:16px; color:#100f26; padding:30px; line-height:24px;}
# .myAccount .planSec strong{font-family: 'Lato bold',sans-serif; font-weight:700; display:block; coor:#212121;}
# .myAccount .planSec span{ display:block; fnot-size:14px; color:#757575;}
# .myAccount .planSec a{font-family: 'Lato bold',sans-serif; font-weight:700; display:block; color:#f7941e; font-size:16px; margin:20px 0 0;}
# .myAccount a.LinkCTA{ display:block; font-family: 'Lato Regular',sans-serif; font-weight:400; font-size:16px; color:#212121; border-top:1px solid #ddd; padding:16px 30px; background:url("/images/SubR.svg") no-repeat 95% 50%;}
# .myAccount a.LinkCTANoArrow{ display:block; font-family: 'Lato Regular',sans-serif; font-weight:400; font-size:16px; color:#212121; border-top:1px solid #ddd; padding:16px 30px; background: no-repeat 95% 50%;}
# @media (max-width: 767px){
# .myAccount{width:0%; background-color: #eee;}
# .myAccount .userDetails{padding:25px;}
# .myAccount .userDetails .initial{ width:82px; height:82px; line-height:82px; font-size:40px; margin:0 auto 20px;}
# .myAccount .planSec, .myAccount a.LinkCTA{padding:16px; margin:16px; box-shadow: 0 1px 2px 0 rgba(0, 0, 0, 0.1); background-color: #fff;}
# }</style>
# <div class="myAccount" id="myAccount">
# <a class="closebtn" href="javascript:void(0)" onclick="closeUserSideProfile()">×</a>
# <div class="userDetails">
# <div class="initial" id="userInitials"></div>
# <div class="uName" id="uName"></div>
# <a href="https://accounts.hindustantimes.com/lm/change_password" id="editProfile" onclick="trackWebEngageEvents('My Account Clicked', {'Button Name':'Change password'});" style="display:none">Change password</a>
# </div>
# <div class="planSec" id="userPlanSec" style="display:none"></div>
# <a class="LinkCTA" href="/myreads">My Reads</a>
# <a class="LinkCTANoArrow" href="https://accounts.hindustantimes.com/logout.html?ref=lm">Logout</a>
# </div>
# <div class="Userbgoverlay" id="Userbgoverlay" onclick="closeUserSideProfile()"></div>
# <script>
# function closePopUp(elm){
# 	var isSubscribedCookie =  getCookie("isSubscribed");
# 	if(isSubscribedCookie!=="undefined" && isSubscribedCookie){
# 		setCookieNewsletter("isSubscribed",isSubscribedCookie,-1);}
# 	if(elm!=="undefined" && elm && document.getElementById(elm)){
# 	document.getElementById("newsltrOvrlay").style.display="none";
# 	document.getElementById(elm).style.display="none";
# 	}
# }
#
# function openUserSideProfile() {
#   closePopUp('thnkNewsletter');
#   getUserData();
#   document.getElementById("myAccount").style.width = "320px";
#   document.getElementById("Userbgoverlay").style.display = "block";
#
#     var trackData = {};
# 	trackWebEngageEvents("My Account Viewed", trackData);
# }
#
# function closeUserSideProfile() {
#   document.getElementById("myAccount").style.width = "0";
#   document.getElementById("Userbgoverlay").style.display = "none";
# }
#
# function getUserData() {
# 	var xhr = new XMLHttpRequest();
# 	xhr.onreadystatechange = function() {
# 	    if (xhr.readyState === 4){
# 	       var data= JSON.parse(xhr.responseText);
# 	       if(data && !data.tokenExpired) {
# 	       		var userData = data;
# 	       		var name = userData.name;
# 	       		var email = userData.email;
# 	       		var signupSource = userData.source;
# 	       		var subscribedAtOnce = userData.subscribedAtOnce;
# 	       		var plan  = userData.plan;
# 	       		var billingCycleText = "Valid Upto";
# 	       		if(signupSource == 'HTDS' || signupSource == 'S' || signupSource == 'C' || signupSource == 'P'){
# 	       			document.getElementById('editProfile').style.display="block";
# 	       		}
#
# 	       		document.getElementById('uName').innerHTML = "<strong>"+name+"</strong>" + email;
# 	       		document.getElementById('userInitials').innerHTML = name[0];
# 	       		if(plan && plan.subscriptions && plan.subscriptions.length > 0) {
# 		       		var planData = plan.subscriptions[0];
# 		       		var status = planData.status;
# 		       		var purchaseSource = planData.source_device;
# 		       		var cancelHtml = "";
# 		       		if(status.indexOf("live") != -1) {
# 		       			//cancelHtml = "<a href='https://accounts.hindustantimes.com/lm/cancelplan' onClick=\"trackWebEngageEvents('My Account Clicked', {'Button Name':'Cancel Plan'});\">Cancel Plan</a>";
# 		       			if(purchaseSource.toLowerCase() == "web"){
# 		       				cancelHtml = "<a href='https://accounts.hindustantimes.com/lm/changeplan' onClick=\"trackWebEngageEvents('My Account Clicked', {'Button Name':'Manage Subscription'});\">Manage Subscription</a>";
# 		       			}
# 		       		}
# 		       		if(status.indexOf("live") != -1 || status.indexOf("non_renewing") != -1){
# 		       			document.getElementById("userPlanSec").style.display = "block";
#
# 			       		if(status.indexOf("non_renewing") != -1){
# 			       			if(purchaseSource.toLowerCase() == "web"){
# 			       				cancelHtml = "<a href='https://accounts.hindustantimes.com/lm/changeplan' onClick=\"trackWebEngageEvents('My Account Clicked', {'Button Name':'Manage Subscription'});\">Manage Subscription</a>";
# 			       			}
# 			       		}
#
# 			       		var nextActivationDate = planData.current_term_ends_at;
# 			       		var nextBillingMonth = new Date(nextActivationDate).toDateString().split(" ")[1];
# 			       		var nextBillingDay = new Date(nextActivationDate).getUTCDate();
# 			       		var nextBillingYear = new Date(nextActivationDate).getFullYear();
# 			       		var planDescription = planData.plan.description;
# 			       		var planName = planData.plan.name;
# 			       		var planPrice = planData.amount;
# 			       		//var planInterval = planData.shipping_interval;
# 			       		var planInterval = planData.duration;
# 			       		var planUnit = planData.interval_unit;
# 			       		var nextBillingHtml = nextBillingDay ? "<span> "+ billingCycleText +" : "+nextBillingDay+" "+nextBillingMonth+" "+nextBillingYear+"</span>" : "";
# 			       		//var html = "<strong>Your Subscription Plan</strong>"+planName+" ₹"+planPrice+" / "+planInterval+" " + nextBillingHtml + cancelHtml;
# 			       		var html = "<strong>Your Subscription Plan</strong> "+planDescription + " "+ planName +": ₹"+planPrice + " "+ nextBillingHtml + cancelHtml;
#
# 			       		document.getElementById('userPlanSec').innerHTML = html;
# 		       		}
# 		       		if(status == "cancelled") {
# 		       		    var renewHtml = "<a href=\"javascript:void(0)\" onClick=\"setOtherFunnelEntry('https://accounts.hindustantimes.com/lm/userplan','My Account','Renew');\">Renew your plan</a>"
# 		       			document.getElementById("userPlanSec").style.display = "block";
# 			       		document.getElementById('userPlanSec').innerHTML = renewHtml;
# 		       		}
# 	       		} else {
# 	       		        document.getElementById("userPlanSec").style.display = "block";
# 			       		document.getElementById('userPlanSec').innerHTML = "<a href=\"javascript:void(0)\" onClick=\"setOtherFunnelEntry('https://accounts.hindustantimes.com/lm/userplan','My Account','Subscribe');\">Subscribe Now</a>";
# 	       		}
# 	       }
# 	    } 	};
# 	xhr.open('GET', '/subscription/fetch/userinfo/'+ window.getCookie("token"));
# 	xhr.send();
# }
# //getUserData();
# </script><script>if(getCookie('isUserLoggedIn') != null && getCookie('isUserLoggedIn')=== 'Yes'){ document.getElementById('outsideSso_'+storyID).style.display = 'none'; } else { if(getCookie('newsletterSubscribedOutsideSso') != null && getCookie('newsletterSubscribedOutsideSso') == 'SUCCESS'){ document.getElementById('outsideSso_'+storyID).style.display = 'none'; } else { document.getElementById('outsideSso_'+storyID).style.display = 'block'; }} </script>
# </div></section></section></section></body></html>

# %%
data.title.text
# Out:
# "Full text of PM Narendra Modi's speech on lockdown, stimulus package"

# %%
data.h1
# Out:
# <h1 class="headline" data-mob="Full text of PM Narendra Modi's speech on lockdown, stimulus package" data-reg="Full text of PM Narendra Modi's speech on lockdown, stimulus package" id="headline_11589312482447">Full text of PM Narendra Modi's speech on lockdown, stimulus package</h1>

# %%
data.findAll("div")
# Out:
# [<div class="desktopAd adSpace" id="div-gpt-ad-1536154100747-0"><script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154100747-0'); });</script></div>,
#  <div class="container"><div class="clearfix"> <a alt="Explore" class="btnSection clearfix" href="javascript:void(0)" onclick="openNav()" title="Explore"><div class="icoMenu"></div><strong>Explore</strong><span id="bluedot"></span></a> <a alt="Livemint" class="logo" href="/" title="Livemint"><img alt="Livemint" src="/images/livemint-logo-v1.svg" title="Livemint"/></a><aside class="headerIcon"><div class="fr"><a alt="Search" class="icoSearch iconSprite" href="javascript:void(0)" onclick="topSearch()" title="Search"></a><a alt="Notification" class="icoBell iconSprite" href="/notifications" title="Notification"><span id="noTCounter" style="display:block;"></span></a><!--<a style = "cursor:pointer;" alt = "Bookmarks" title = "Bookmarks" onClick = "bookMarkHome();" class="icoBookmark iconSprite" ></a>--><a class="userSignin" href="https://accounts.hindustantimes.com/?type=plain&amp;ref=lm" onclick="webengage.track('Click',  {'buttonName': 'Home_Tab_Login'});">Sign in</a><a alt="E-Paper" class="epaper" href="http://epaper.livemint.com" target="_blank" title="E-Paper">e-paper<span>New</span></a> </div><div class="clear"></div><div class="headerDate" id="currentDate"><span id="showCurrentDateTime">Friday, 10 July 2020</span> <span id="showWeather"></span></div></aside></div></div>,
#  <div class="clearfix"> <a alt="Explore" class="btnSection clearfix" href="javascript:void(0)" onclick="openNav()" title="Explore"><div class="icoMenu"></div><strong>Explore</strong><span id="bluedot"></span></a> <a alt="Livemint" class="logo" href="/" title="Livemint"><img alt="Livemint" src="/images/livemint-logo-v1.svg" title="Livemint"/></a><aside class="headerIcon"><div class="fr"><a alt="Search" class="icoSearch iconSprite" href="javascript:void(0)" onclick="topSearch()" title="Search"></a><a alt="Notification" class="icoBell iconSprite" href="/notifications" title="Notification"><span id="noTCounter" style="display:block;"></span></a><!--<a style = "cursor:pointer;" alt = "Bookmarks" title = "Bookmarks" onClick = "bookMarkHome();" class="icoBookmark iconSprite" ></a>--><a class="userSignin" href="https://accounts.hindustantimes.com/?type=plain&amp;ref=lm" onclick="webengage.track('Click',  {'buttonName': 'Home_Tab_Login'});">Sign in</a><a alt="E-Paper" class="epaper" href="http://epaper.livemint.com" target="_blank" title="E-Paper">e-paper<span>New</span></a> </div><div class="clear"></div><div class="headerDate" id="currentDate"><span id="showCurrentDateTime">Friday, 10 July 2020</span> <span id="showWeather"></span></div></aside></div>,
#  <div class="icoMenu"></div>,
#  <div class="fr"><a alt="Search" class="icoSearch iconSprite" href="javascript:void(0)" onclick="topSearch()" title="Search"></a><a alt="Notification" class="icoBell iconSprite" href="/notifications" title="Notification"><span id="noTCounter" style="display:block;"></span></a><!--<a style = "cursor:pointer;" alt = "Bookmarks" title = "Bookmarks" onClick = "bookMarkHome();" class="icoBookmark iconSprite" ></a>--><a class="userSignin" href="https://accounts.hindustantimes.com/?type=plain&amp;ref=lm" onclick="webengage.track('Click',  {'buttonName': 'Home_Tab_Login'});">Sign in</a><a alt="E-Paper" class="epaper" href="http://epaper.livemint.com" target="_blank" title="E-Paper">e-paper<span>New</span></a> </div>,
#  <div class="clear"></div>,
#  <div class="headerDate" id="currentDate"><span id="showCurrentDateTime">Friday, 10 July 2020</span> <span id="showWeather"></span></div>,
#  <div class="searchHolder"><div class="container clearfix"><div class="inputHolder"><input class="inputText" id="searchParameter" name="searchParameter" onblur="if(this.value=='')this.value='';" onfocus="if(this.value=='Search')this.value='';" onkeyup="return basicSearch(event,'searchParameter','1')" placeholder="Type here to search" type="text"/><div class="ajax_response" id="ajax_response_1"></div></div><input class="btnSearch" disabled="" name="btnSearch" onclick="return basicSearch('1','searchParameter');" type="button" value="Search"/></div></div>,
#  <div class="container clearfix"><div class="inputHolder"><input class="inputText" id="searchParameter" name="searchParameter" onblur="if(this.value=='')this.value='';" onfocus="if(this.value=='Search')this.value='';" onkeyup="return basicSearch(event,'searchParameter','1')" placeholder="Type here to search" type="text"/><div class="ajax_response" id="ajax_response_1"></div></div><input class="btnSearch" disabled="" name="btnSearch" onclick="return basicSearch('1','searchParameter');" type="button" value="Search"/></div>,
#  <div class="inputHolder"><input class="inputText" id="searchParameter" name="searchParameter" onblur="if(this.value=='')this.value='';" onfocus="if(this.value=='Search')this.value='';" onkeyup="return basicSearch(event,'searchParameter','1')" placeholder="Type here to search" type="text"/><div class="ajax_response" id="ajax_response_1"></div></div>,
#  <div class="ajax_response" id="ajax_response_1"></div>,
#  <div class="container">
#  </div>,
#  <div class="icosubscription"></div>,
#  <div>Subscribe</div>,
#  <div class="icoSearch2"></div>,
#  <div>Search</div>,
#  <div class="icoEpaper"></div>,
#  <div>e-paper</div>,
#  <div class="icosmartcast"></div>,
#  <div>Podcasts</div>,
#  <div class="icoBell iconSprite" style="margin:0 10px 0 0; display:block;"></div>,
#  <div>Notifications</div>,
#  <div class="iconewsletter"></div>,
#  <div>Newsletters</div>,
#  <div class="menuTitle">Top Sections</div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="subnavArrow" onclick="submenu(this.parentElement)"><img alt="" src="/images/nav-arrow.svg"/></div>,
#  <div class="menuTitle">Explore Mint</div>,
#  <div class="copyright">Copyright © HT Media Limited All rights reserved.</div>,
#  <div class="mobileAd adHolder adHolderTop" id="pushDownAd"><div id="div-gpt-ad-1536154373501-0"> <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154373501-0'); });</script></div></div>,
#  <div id="div-gpt-ad-1536154373501-0"> <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154373501-0'); });</script></div>,
#  <div class="bcrumb pb16"><a href="/">Home</a> &gt;<a href="/News">News</a> &gt;<a href="/News/India">India</a> &gt;Full text of PM Narendra Modi's speech on lockdown, stimulus package</div>,
#  <div class="clearfix socialHolder">
#  <aside class="fl"><a class="icoBookmark3 iconSprite marZero bookmark-candidate bookmark_11589312482447" data-vars-storyid="11589312482447" id="bookmark_11589312482447" onclick="bookmarkFunc(this)"></a> <a class="icoFB iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a> <a class="icowhatsapp iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a> <a class="icolinkedin iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a> <a class="icoTwit iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Twitter');" title="Tweet"></a><div class="blankOverlay" onclick="shareIcon(this)"></div><div class="icoShare iconSprite" onclick="share(this)"><div class="icoSec"><span></span><div>Share Via</div><a class="icoFB2 iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a><a class="icowhatsapp2 iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a><a class="icolinkedin2 iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a><a class="icoTwit2 iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdow ...
#  </div>,
#  <div class="blankOverlay" onclick="shareIcon(this)"></div>,
#  <div class="icoShare iconSprite" onclick="share(this)"><div class="icoSec"><span></span><div>Share Via</div><a class="icoFB2 iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a><a class="icowhatsapp2 iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a><a class="icolinkedin2 iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a><a class="icoTwit2 iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Twitter');" title="Tweet"></a></div></div>,
#  <div class="icoSec"><span></span><div>Share Via</div><a class="icoFB2 iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a><a class="icowhatsapp2 iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a><a class="icolinkedin2 iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a><a class="icoTwit2 iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Twitter');" title="Tweet"></a></div>,
#  <div>Share Via</div>,
#  <div class="adHolderStory storyadHolderAfterLoad" id="story-ads-0">
#  <script>googletag.cmd.push(function() { googletag.display('story-ads-0'); });</script>
#  </div>,
#  <div class="contentSec">
#  <div>
#  <div class="mainArea" id="mainArea">
#  <div class="FirstEle">
#  <p>
#  In an address to the nation, Prime Minister Narendra Modi hinted at a continuation of the lockdown India has been under for several weeks but added that the coming phase would be “totally different" from the previous phases, the contours of which will be decided based on the suggestions given by states.</p> </div>
#  <p>The question is - how?</p>
#  <p>The answer to this question is – A Combined resolve of 130 crore citizens for a self-reliant India.</p>
#  <p>Friends,</p>
#  <p>We have a proud history of centuries. When India was prosperous, it was called the golden goose, it was prosperous, and then it always walked tall for the welfare of the world.</p>
#  <p>Then the times changed, the country was caught in the chains of slavery, we longed for development. Today, when India is making rapid strides in its progress, it is still committed to the goal of global welfare. Remember, the Y2K crisis at the beginning of this century. Technology experts from India pulled the world out of that crisis. Today we have the resources, we have the power, and we have the best talent in the world.</p>
#  <p>We will make the best products, will improve our quality further, make the supply chain more modern, we can do this and we will definitely do it.</p>
#  <p>Friends,</p>
#  <p>I had witnessed the Kutch earthquake. There was debris everywhere. Everything was destroyed. It seemed as if Kutch had fallen asleep wearing a sheet of death. In that situation no one could have imagined that the situation would ever change. However, Kutch stood up, Kutch started moving, Kutch moved. This is the grit and determination of weIndians.</p>
#  <p>If we are determined then we can reach our goals and no path will be difficult. And today there is a will and there is a way. That is to make India self-reliant. Our combined resolve is so strong that India can become self-sufficient.</p>
#  <p>Friends, this magnificent building of self-reliant India will stand on five Pillars.</p>
#  <p><strong>First Pillar is Economy</strong>, an economy that brings Quantum Jump rather than Incremental change.</p>
#  <p><strong>Second Pillar is Infrastructure</strong>, an infrastructure that became the identity of modern India.</p>
#  <p><strong>Third Pillar is Our System</strong>. A system that is driven by technology which canfulfill the dreams of the 21st century; a system not based on the policy of the past century.</p>
#  <p><strong>Fourth Pillar is Our Demography</strong>. Our Vibrant Demography is our strength in the world's largest democracy, our source of energy for self-reliant India.</p>
#  <p><strong>The fifth pillar is Demand</strong>. The cycle of demand and supply chain in our economy, is the strength that needs to be harnessed to its full potential. In order to increase demand in the country and to meet this demand, every stake-holder in our supply chain needs to be empowered. We will strengthen our supply chain, our supply system built up with the smell of the soil and the sweat of our labourers.</p>
#  <p>Friends, amidst the Corona crisis, I am announcing today a special economic package with a new resolution. This economic package will serve as an important link in the 'AtmaNirbhar Bharat Abhiyan" (Self Reliant India Campaign)'.</p>
#  <p>Friends, in the recent past economic announcements made by the government related to the Corona crisis, which were the decisions of the Reserve Bank. The economic package that is being announced today, if added, comes to around Rs. 20 lakh crores. This package is about 10 percent of India's GDP. With this various sections of the country and those linked to economic system will get support and strength of 20 lakh crore rupees. This package will give a new impetus to the development journey of the country in 2020 and a new direction to the Self-reliant India campaign. In order to prove the resolve of a self-reliant India, Land, Labor, Liquidity and Laws all have been emphasized in this package.</p>
#  <p>This economic package is for our cottage industry, home industry, our small-scale industry, our MSME, which is a source of livelihood for millions of people, which is the strong foundation of our resolve for a self-reliant India. This economic package is for that labourer of the country, for the farmers of the country who are working day and night for the countrymen in every situation, every season. This economic package is for the middle class of our country, which pays taxes honestly and contributes to the development of the country. This economic package is for Indian industries, which are determined to give a boost to the economic potential of India. Starting tomorrow, over the next few days, the Finance Minister will give you detailed information about this economic package inspired by the 'Self-reliant India campaign'.</p>
#  <p>Friends, it is now imperative for the country to move forward with the commitment of Bold Reforms to create a self-reliant India. You have also experienced that as a result of the reforms over the past 6 years, today even in this time of crisis; India's systems have looked more efficient. Otherwise, who could have thought that the money sent by Government of India will reach directly in the pocket of the poor farmer! But it has happened. That also happened when all the government offices were closed; the means of transport were shut down.This was just a reform related to Janadhan-Aadhaar-Mobile-JAM's Trishakti, the effect of which we have just seen. Now the scope of the reforms has to be broadened, giving a new height. These reforms will be in the entire supply chain related to farming, so that the farmer is also empowered and will have minimal impact on agriculture in any other crisis like corona in future. These reforms will be for, rational tax system, simple and clear rules-of-law, good infrastructure, capable and competent human resources, and building strong financial system. These reforms will encourage business, attract investment and strengthen our resolve for Make in India.</p>
#  <p>Friends, self-reliance is possible only through inner strength and self-belief. Self-reliance also prepares the country for a tough competition in the global supply chain. And today it is the need of the hour that India should play a big role in the global supply chain. Realizing this, many provisions have also been made in the economic package. This will increase the efficiency of all our sectors and also ensure quality.</p>
#  <p>Friends, this crisis is so big, that the biggest systems have been shaken. However, under these circumstances, the country has also seen the resolve and restraint of our poor brothers and sisters, especially the street vendors, hawkers, labourers, those who are working in homes, they have done a lot of penance during this time, they have sacrificed a lot. Who would not have realized their absence? Now it is our duty to make them strong, to take some big steps for their financial requirements. Keeping this in mind, be it poor, labourers, migrant labourers, cattle rearers, be our fishermen, organized sector or unorganized sector, some important decisions will be announced in the economic package for every section.</p>
#  <p>Friends, the Corona crisis has also explained to us the importance of Local manufacturing, Local market and Local supply chain. In times of crisis, this Local has fulfilled our demand, this Local has saved us. Local is not just the need, it is our responsibility also. Time has taught us that we must make the Local as a mantra of our life. The Global Brands you feel today were sometimes also very local like this. But when people started using them, started promoting them, branding them, proud of them, they became Global from Local Products. Therefore, from today every Indian has to become vocal for their local, not only to buy local products, but also to promote them proudly. I am confident that our country can do this. Your efforts have increased my reverence for you every time. I recollect one thing with pride. When I requested you and the nation to buyKhadi and said it will be a great support to our handloom workers. Today, the demand and sales of both Khadi and handloom have reached record levels in a very short time. Not only that, you also made it a big brand. It was a very small effort, but the result was very good.</p>
#  <p>Friends, experts and scientists have pointed out that Corona will remain a part of our lives for a long time. But at the same time, we cannot allow this to happen that our lives will be confined only around the corona. We would wear masks, follow two yards distance and pursue our goals. Therefore, the fourth phase of lockdown, lockdown 4, will be completely redesigned, with new rules. Based on the suggestions we are getting from the states, information related to Lockdown 4 will also be given to you before 18 May. I am confident that by following the rules, we will fight Corona and move forward.</p>
#  <p>Friends, In our culture, it is said 'सर्वम् आत्म वशं सुखम्' i.e. what is in our control, is happiness. Self-reliance leads to happiness, satisfaction and empowerment. Our responsibility to make the 21st century, the century of India, will be fulfilled by the pledge of self-reliant India. This responsibility will only get energy from the life force of 130 crore citizens. This era of self-reliant India will be a new vow for every Indian as well as a new festival. Now we have to move forward with a new resolve and determination. When ethics are filled with duty, the culmination of diligence, the capital of skills, then who can stop India from becoming self-reliant? We can make India a self-reliant nation. We will make India self-reliant. With this resolve, with this belief, I wish you the very best.</p>
#  <div class="newslettersub_outsidesso_11589312482447">
#  <div class="outsideSso clearfix" id="outsideSso_11589312482447">
#  <div class="label">Subscribe to <strong>newsletters</strong></div>
#  <div class="inputSecArea clearfix" id="inputSec_11589312482447">
#  <form action="#" name="form1">
#  <input class="inputemail" id="emailSso_11589312482447" name="emailSso_11589312482447" onkeyup="manage(this,11589312482447)" placeholder="Enter email address" type="text"/>
#  <input class="subscribeBtn" disabled="" id="btSubmit_11589312482447" onclick="ValidateEmail('emailSso_11589312482447')" type="button" value="Subscribe"/>
#  </form>
#  <div class="msgError"><span>*</span> Enter a valid email</div>
#  <div class="msgOk"><span>*</span> Thank you for subscribing to our newsletter.</div>
#  <div class="ssoCaptha" id="ssoCaptha_11589312482447">
#  <div class="g-recaptcha box" id="recaptcha_11589312482447"></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="clearfix socialHolder"><aside class="fl"><a class="icoBookmark3 iconSprite marZero bookmark-candidate bookmark_11589312482447" data-vars-storyid="11589312482447" id="bookmark_11589312482447" onclick="bookmarkFunc(this)"></a> <a class="icoFB iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a> <a class="icowhatsapp iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a> <a class="icolinkedin iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a> <a class="icoTwit iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Twitter');" title="Tweet"></a><div class="blankOverlay" onclick="shareIcon(this)"></div><div class="icoShare iconSprite" onclick="share(this)"><div class="icoSec"><span></span><div>Share Via</div><a class="icoFB2 iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a><a class="icowhatsapp2 iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a><a class="icolinkedin2 iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a><a class="icoTwit2 iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of P ...
#  <div class="epaperPromo"><p><span><a class="desktopTxt" href="https://epaper.livemint.com/Home/ArticleView?utm_source=livemintstory&amp;utm_medium=lmstorybottom&amp;utm_campaign=lmstoryref" target="_blank">Click here</a> to read the Mint ePaper</span>Livemint.com is now on Telegram.<a href="https://t.me/livemint" target="_blank"> Join Livemint channel</a> in your Telegram and stay updated</p></div><div class="lastAdSlot clearfix" id="lastAd"></div></div></div>
#  <a class="btnClose sticky2 close-btn" data-vars-storyid="11589312482447" href="#box_11589312482447" onclick="collapseStory(this,'11589312482447')">Close</a>
#  </div>
#  <div class="pageurldiv" data-page="2" data-pageurl="/"></div>
#  <div class="listView" id="mylistView"></div>
#  <script>//document.getElementById("readMore_11589312482447").style.display="none";</script>
#  <script>
#  var type;
#  var refURL = document.referrer;
#  if(window.location.search != "") {
#   var urlParams = new URLSearchParams(window.location.search);
#   if(urlParams.has('type') == true) {
#     type = urlParams.get('type');
#   }
#  }
#
#  function setCookieStory(cname, cvalue, exdays) {var d = new Date; d.setTime(d.getTime() + exdays * 24 * 60 * 60 * 1000); var expires = "expires=" + d.toUTCString(); document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/"; }
#  function getParameterByName() {
#    const urlParams = new URLSearchParams(window.location.search);
#    if(urlParams.get('utm_source') != null && urlParams.get('utm_source') != "") {
#       setCookieStory("utm_source",urlParams.get('utm_source'),.0208);
#        }
#
#    if(urlParams.get('utm_medium') != null && urlParams.get('utm_medium') != "") {
#       setCookieStory("utm_medium",urlParams.get('utm_medium'),.0208);
#        }
#
#    if(urlParams.get('utm_campaign') != null && urlParams.get('utm_campaign') != "") {
#       setCookieStory("utm_campaign",urlParams.get('utm_campaign'),.0208);
#         }
#
#
#  }
#   getParameterByName();
#  window.history.replaceState(null,"","/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html");
#  function bodyExpand(id) {
#      if(document.getElementById("story-ads-0")!==null){
#        document.getElementById("story-ads-0").style.display="block";
#      }
#      document.getElementById('box_11589312482447').classList.add('open');
#      document.getElementById("tBox_"+id).innerHTML= document.getElementById("tBox_"+id).getAttribute("data-expandedtime");
#      //alert(document.getElementById("headline_"+id).getAttribute("data-reg"));
#      document.getElementById("headline_"+id).innerHTML= document.getElementById("headline_"+id).getAttribute("data-reg");
#  }
#
#  function parseURL(url) {
#      var a=document.createElement('a');
#      a.href=url;
#      return a.hostname;
#  }
#
#  function collapseStory(box,id) {
#     if(document.getElementById("story-ads-0")!==null){
#        document.getElementById("story-ads-0").style.display="none";
#     }
#
#      collapse(box);
#      document.getElementById("readMore_"+id).style.display="";
#
#      /*
#      //alert(refURL);
#      if(refURL=="") {
#          collapse(box);
#          document.getElementById("readMore_"+id).style.display="";
#      } else {
#          if((parseURL(refURL) == "localhost" || parseURL(refURL) == "pre-prod.livemint.com" || parseURL(refURL) == "livemint.com" || parseURL(refURL) == "staging.livemint.com") && refURL.includes(".html") == false) {
#             if(typeof type != undefined) {
#                 if(type == "card") {
#                  location.href = refURL+"#box_"+id;
#                 }
#                     else if(type == "collection") {
#                     location.href = refURL+"#lc_"+id;
#                 }
#                     else if(type == "list") {
#                     location.href = refURL+"#listBox_"+id;
#                 }
#                 else {
#                  location.href = refURL;
#                 }
#             } else {
#             location.href = refURL;
#             }
#          } else {
#          collapse(box);
#          document.getElementById("readMore_"+id).style.display="";
#          }
#      }*/
#
#  }
#  var pagePagination = "1";
#  var pageName = "story";
#   var sLash = "/";
#  var onScrollPage = sLash + "onScrollFullStoryListing";
#  </script>
#  <div class="adRight" id="div-gpt-ad-1536154161359-0" style="height:250px; width:300px;">
#  <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154161359-0');});</script></div>
#  <div class="adRight vSpace lastAd" id="div-gpt-ad-1536154273332-0" style="height:600px; width:300px;">
#  <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154273332-0');  googletag.pubads().refresh();});</script></div>
#  <div class="bkmrmsg" id="networkToast" style="display:none;"><span>No Network</span></div><div class="bkmrmsg" id="serverToast" style="display:none;"><span>Server Issue</span></div><div class="bkmrmsg" id="internetConnectionToast" style="display:none;"><span>Internet Not Available</span></div><div class="whiteOverlay" onclick="hideSearch()"></div><div class="whiteOverlay2" onclick="closeNav()"></div><div class="popupsection" id="loginpopup"><div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginpopup').style.display='none';" style="cursor:pointer;"></a><h4>Wait for it…</h4><p>Log in to our website to save your bookmarks. It'll just take a moment.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div></div></div> <div class="popupsection" id="loginReminderPopUp"><div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginReminderPopUp').style.display='none';" style="cursor:pointer;"></a><p>Your session has expired, please login again.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div></div></div><style>
#
#
#      #eclt-rsttbleflip{font-family: "Open Sans", sans-serif; bottom: 47px; height: 95px; margin: 10px auto; right:20px; position: fixed; width: 100px; z-index: 99999; background: none; border: none;padding: 0;}
#
#  #eclt-rsttbleflipdash{-webkit-perspective:1000;perspective:1000;-webkit-transform-style:preserve-3d}
#  #eclt-rsttbleflipdash{width:100%;height:100%;-webkit-transform-style:preserve-3d;transform-style:preserve-3d;-webkit-transition:all 1.0s linear;transition:all 1.0s linear}
#  .loadable{position:absolute;width:100%;height:100%;-webkit-backface-visibility:hidden;backface-visibility:hidden;
#    border: 1px solid #ff0808;
#    border-radius: 5px;
#  }
#  #election0,#election1{-moz-box-shadow:0 0 9px #000;-webkit-box-shadow:0 0 9px #000;box-shadow:0 0 9px #000;box-sizing:border-box;padding:0 0px}
#  #eclt-rsttbleflipdash .state-name{font-size:18px;line-height:29px;display:block;text-align:center;text-transform:uppercase;font-weight:bold}
#  #eclt-rsttbleflipdash .result-table-list li:not(:last-child){margin-bottom:3px}
#  #election0{background-color:#fff;color:000;-webkit-transform:rotateY(-180deg);transform:rotateY(-180deg);-webkit-animation:mymoveback 10s infinite;animation:mymoveback 10s infinite}
#  #election1{display:block;box-sizing:border-box;color:000;background-color:#fff;-webkit-animation:mymove 10s infinite;animation:mymove 10s infinite}
#
#  #election3{display:block;box-sizing:border-box;color:000;background-color:#fff;
#    background-color:#fff;color:000;-webkit-transform:rotateY(-360deg);transform:rotateY(-360deg);
#    -webkit-animation:mymoveback360 10s infinite;animation:mymoveback360 10s infinite}
#  .eclt-rsttble .fll-covrge { color: #000; display: block;
#  border-radius: 5px;  text-align: center; font-size: 14px; }
#  .eclt-rsttble a.fll-covrge{text-decoration: none;}
#  .fll-covrge span { background: #ff0808; padding: 6px 10px; color: #fff; font-size: 16px; display: block; }
#  .fll-covrge ul { margin: 0; padding: 0; }
#  .fll-covrge ul li { display: block; background:none; padding:0; line-height:14px; font-family: 'Lato Regular',sans-serif; font-size:14px;}
#  .fll-covrge ul li  span  { background: none; display: block; width: 100%; font-weight:600; font-size: 14px; padding:5px 0 0 0; color: #000; text-align: center;  }
#  .eclt-rsttble .fll-covrge small { border:1px solid #b4353b; padding:3px 0 1px 7px; text-align:center; font-size:15px; display:block; max-width:63px;color: #b4353b; margin:0 auto 5px; position:relative; }
#  .eclt-rsttble .fll-covrge small:before {     content: ""; height: 8px; width: 8px; border-radius: 100%; display: inline-block;
#  background: #af272d;position: absolute;left: 3px; top: 8px;}
#
#  @-webkit-keyframes mymove{40%{-webkit-transform:rotateY(0deg)}
#  50%{-webkit-transform:rotateY(180deg)}
#  90%{-webkit-transform:rotateY(180deg)}
#  100%{-webkit-transform:rotateY(0deg)}
#  }
#  @-webkit-keyframes mymoveback{40%{-webkit-transform:rotateY(-180deg)}
#  50%{-webkit-transform:rotateY(0deg)}
#  90%{-webkit-transform:rotateY(0deg)}
#  100%{-webkit-transform:rotateY(-180deg)}
#  }
#  @-webkit-keyframes mymoveback360{40%{transform:rotateY(-360deg)}
#  50%{transform:rotateY(0deg)}
#  90%{transform:rotateY(0deg)}
#  100%{transform:rotateY(-360deg)}
#  }
#  @keyframes mymove{40%{transform:rotateY(0deg)}
#  50%{transform:rotateY(180deg)}
#  90%{transform:rotateY(180deg)}
#  100%{transform:rotateY(0deg)}
#  }
#  @keyframes mymoveback{40%{transform:rotateY(-180deg)}
#  50%{transform:rotateY(0deg)}
#  90%{transform:rotateY(0deg)}
#  100%{transform:rotateY(-180deg)}
#  }
#
#  .crossbutton {
#     border: 1px solid #ff0808;
#     transform: rotate(45deg);
#     width: 21px;
#     height: 21px;
#     margin: -12px 0 0 -12px;
#     float: left;
#     border-radius: 50%;
#     background: #FFF;
#     box-sizing:border-box;
#     position: absolute;
#     cursor: pointer;
#     z-index:10;
#  }
#
#  .crossbutton:after {
#     position: absolute;
#     content: '';
#     top: 9px;
#     left: 5px;
#     width: 9px;
#     height: 1px;
#     background: #ff0808;
#  }
#
#  .crossbutton:before {
#     position: absolute;
#     content: '';
#     top: 5px;
#     left: 9px;
#     height: 9px;
#     width: 1px;
#     background: #ff0808;
#  }
#
#      </style>
#  <div class="clearfix" id="corona-div" style="display:none;">
#  <div class="eclt-rsttble" id="eclt-rsttbleflip" style="display:none;">
#  <div class="shadow" id="eclt-rsttbleflipdash">
#  </div>
#  </div>
#  </div>
#  <script>
#  function getCookieCorona(name) {var nameEQ = name + "="; var ca = document.cookie.split(";"); for (var i = 0; i < ca.length; i++) {var c = ca[i]; while (c.charAt(0) == " ") {c = c.substring(1, c.length); } if (c.indexOf(nameEQ) == 0) {return c.substring(nameEQ.length, c.length); } } return null; }
#  function setCookieCorona(cname, cvalue, exdays) {var d = new Date; d.setTime(d.getTime() + exdays * 24 * 60 * 60 * 1000); var expires = "expires=" + d.toUTCString(); document.cookie = cname + "=" + cvalue + ";" + expires + ";path=/"; }
#      var corona=getCookieCorona("corona");
#  if(corona){
#  	document.getElementById("corona-div").style.display = "none";
#  } else {
#  document.getElementById("corona-div").style.display = "block";
#    getHTTPRequestCorona("https://www.livemint.com/feed-elections/5m/coronavirus.json", "eclt-rsttbleflipdash", true);
#  }
#  function getFirstKey(obj) {
#      for (key in obj) {
#          return key;
#      }
#  }
#
#  function hideCross() {
#  document.getElementById("corona-div").style.display = "none";
#    if(typeof setCookieCorona!=='undefined'){
#  	setCookie("corona","true",1);
#     }
#  }
#  function getHTTPRequestCorona(url, id, json) {
#      var xhttp = new XMLHttpRequest;
#      if (json == true) {
#          xhttp.responseType = "json";
#      }
#      xhttp.open("GET", url, true);
#      xhttp.send();
#      xhttp.onreadystatechange = function() {
#      if (xhttp.readyState == 4 && xhttp.status == 200) {
#           var objResponse = xhttp.response;
#           var flipText = "";
#           if(objResponse.data_eng!=null && objResponse.data_eng!==undefined && objResponse.data_eng!=''){
#           		[].forEach.call(objResponse.data_eng, function(el, i){
#           		flipText = flipText + '<div class="widget-inner loadable" id="election'+i+'"><div class="crossbutton" onClick = "hideCross();"></div><a class="fll-covrge" href="/topic/coronavirus"><span>COVID-19</span><ul id="t'+(i+1)+'"><li><span>'+getFirstKey(el)+'</span><span>'+el[getFirstKey(el)]+'</span></li></ul></a></div>';
#            		 });
#
#           		}
#           		document.getElementById("eclt-rsttbleflip").style.display = "block";
#  			    document.getElementById('eclt-rsttbleflipdash').innerHTML = flipText;
#        }
#      }
#   }
# ...
#  <div class="blankOverlay" onclick="shareIcon(this)"></div>,
#  <div class="icoShare iconSprite" onclick="share(this)"><div class="icoSec"><span></span><div>Share Via</div><a class="icoFB2 iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a><a class="icowhatsapp2 iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a><a class="icolinkedin2 iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a><a class="icoTwit2 iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Twitter');" title="Tweet"></a></div></div>,
#  <div class="icoSec"><span></span><div>Share Via</div><a class="icoFB2 iconSprite share-candidate" data-vars-icontype="facebook" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('http://www.facebook.com/sharer/sharer.php?u=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html'); trackEventBuild('News','India', 'Facebook');" title="Facebook Share"></a><a class="icowhatsapp2 iconSprite share-candidate" data-vars-icontype="whatsapp" data-vars-storyid="11589312482447" href="https://api.whatsapp.com/send?text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package - https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html %0a%0a%0aDownload mint app for latest in Business News - https://bit.ly/32XEfFE" onclick="trackEventBuild('News','India', 'Whatsapp');" target="_blank"></a><a class="icolinkedin2 iconSprite share-candidate" data-vars-icontype="linkedin" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://www.linkedin.com/cws/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;title=Full text of PM Narendra Modi's speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Linkedin');" target="_blank" title="Linkedin Share"></a><a class="icoTwit2 iconSprite share-candidate" data-vars-icontype="twitter" data-vars-storyid="11589312482447" href="javascript:void(0)" onclick="sharePage('https://twitter.com/share?url=https://www.livemint.com/news/india/full-text-of-pm-narendra-modi-s-speech-on-lockdown-stimulus-package-11589312482447.html&amp;text=Full text of PM Narendra Modi‘s speech on lockdown, stimulus package'); trackEventBuild('News','India', 'Twitter');" title="Tweet"></a></div>,
#  <div>Share Via</div>,
#  <div class="epaperPromo"><p><span><a class="desktopTxt" href="https://epaper.livemint.com/Home/ArticleView?utm_source=livemintstory&amp;utm_medium=lmstorybottom&amp;utm_campaign=lmstoryref" target="_blank">Click here</a> to read the Mint ePaper</span>Livemint.com is now on Telegram.<a href="https://t.me/livemint" target="_blank"> Join Livemint channel</a> in your Telegram and stay updated</p></div>,
#  <div class="lastAdSlot clearfix" id="lastAd"></div>,
#  <div class="pageurldiv" data-page="2" data-pageurl="/"></div>,
#  <div class="listView" id="mylistView"></div>,
#  <div class="adRight" id="div-gpt-ad-1536154161359-0" style="height:250px; width:300px;">
#  <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154161359-0');});</script></div>,
#  <div class="adRight vSpace lastAd" id="div-gpt-ad-1536154273332-0" style="height:600px; width:300px;">
#  <script>googletag.cmd.push(function() { googletag.display('div-gpt-ad-1536154273332-0');  googletag.pubads().refresh();});</script></div>,
#  <div class="bkmrmsg" id="networkToast" style="display:none;"><span>No Network</span></div>,
#  <div class="bkmrmsg" id="serverToast" style="display:none;"><span>Server Issue</span></div>,
#  <div class="bkmrmsg" id="internetConnectionToast" style="display:none;"><span>Internet Not Available</span></div>,
#  <div class="whiteOverlay" onclick="hideSearch()"></div>,
#  <div class="whiteOverlay2" onclick="closeNav()"></div>,
#  <div class="popupsection" id="loginpopup"><div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginpopup').style.display='none';" style="cursor:pointer;"></a><h4>Wait for it…</h4><p>Log in to our website to save your bookmarks. It'll just take a moment.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div></div></div>,
#  <div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginpopup').style.display='none';" style="cursor:pointer;"></a><h4>Wait for it…</h4><p>Log in to our website to save your bookmarks. It'll just take a moment.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div></div>,
#  <div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginpopup').style.display='none';" style="cursor:pointer;"></a><h4>Wait for it…</h4><p>Log in to our website to save your bookmarks. It'll just take a moment.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div>,
#  <div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginpopup').style.display='none';" style="cursor:pointer;"></a><h4>Wait for it…</h4><p>Log in to our website to save your bookmarks. It'll just take a moment.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div>,
#  <div class="btn">Yes, Continue</div>,
#  <div class="popupsection" id="loginReminderPopUp"><div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginReminderPopUp').style.display='none';" style="cursor:pointer;"></a><p>Your session has expired, please login again.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div></div></div>,
#  <div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginReminderPopUp').style.display='none';" style="cursor:pointer;"></a><p>Your session has expired, please login again.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div></div>,
#  <div class="vertical-align-center"><div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginReminderPopUp').style.display='none';" style="cursor:pointer;"></a><p>Your session has expired, please login again.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div></div>,
#  <div class="popup"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('loginReminderPopUp').style.display='none';" style="cursor:pointer;"></a><p>Your session has expired, please login again.</p><a href="https://accounts.hindustantimes.com" target="_blank"><div class="btn">Yes, Continue</div></a></div>,
#  <div class="btn">Yes, Continue</div>,
#  <div class="clearfix" id="corona-div" style="display:none;">
#  <div class="eclt-rsttble" id="eclt-rsttbleflip" style="display:none;">
#  <div class="shadow" id="eclt-rsttbleflipdash">
#  </div>
#  </div>
#  </div>,
#  <div class="eclt-rsttble" id="eclt-rsttbleflip" style="display:none;">
#  <div class="shadow" id="eclt-rsttbleflipdash">
#  </div>
#  </div>,
#  <div class="shadow" id="eclt-rsttbleflipdash">
#  </div>,
#  <div class="popupsection" id="subReminderPopUp" style="display: none;"><div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup p20"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('subReminderPopUp').style.display='none';" style="cursor:pointer;"></a><img alt="" class="lozad" data-src="/images/subscribe-for-free.svg" src="/images/static/1x1_img.gif"/><h3>Congratulations!</h3><p>You are now subscribed to our newsletters. In case you can’t find any email from our side, please check the spam folder.</p></div></div></div></div>,
#  <div class="whiteOverlay3"><div class="vertical-align-center"><div class="popup p20"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('subReminderPopUp').style.display='none';" style="cursor:pointer;"></a><img alt="" class="lozad" data-src="/images/subscribe-for-free.svg" src="/images/static/1x1_img.gif"/><h3>Congratulations!</h3><p>You are now subscribed to our newsletters. In case you can’t find any email from our side, please check the spam folder.</p></div></div></div>,
#  <div class="vertical-align-center"><div class="popup p20"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('subReminderPopUp').style.display='none';" style="cursor:pointer;"></a><img alt="" class="lozad" data-src="/images/subscribe-for-free.svg" src="/images/static/1x1_img.gif"/><h3>Congratulations!</h3><p>You are now subscribed to our newsletters. In case you can’t find any email from our side, please check the spam folder.</p></div></div>,
#  <div class="popup p20"><a class="icoClose iconSprite" onclick="javascript:document.getElementById('subReminderPopUp').style.display='none';" style="cursor:pointer;"></a><img alt="" class="lozad" data-src="/images/subscribe-for-free.svg" src="/images/static/1x1_img.gif"/><h3>Congratulations!</h3><p>You are now subscribed to our newsletters. In case you can’t find any email from our side, please check the spam folder.</p></div>,
#  <div class="adMweb"><div id="div-gpt-ad-1563523997184-0"> <script> googletag.cmd.push(function() { googletag.display('div-gpt-ad-1563523997184-0'); }); </script> </div></div>,
#  <div id="div-gpt-ad-1563523997184-0"> <script> googletag.cmd.push(function() { googletag.display('div-gpt-ad-1563523997184-0'); }); </script> </div>,
#  <div class="modal" id="myModalZoomBox"><span class="close">×</span><img class="modal-content" id="img01"/><div id="caption"></div></div>,
#  <div id="caption"></div>,
#  <div class="myAccount" id="myAccount">
#  <a class="closebtn" href="javascript:void(0)" onclick="closeUserSideProfile()">×</a>
#  <div class="userDetails">
#  <div class="initial" id="userInitials"></div>
#  <div class="uName" id="uName"></div>
#  <a href="https://accounts.hindustantimes.com/lm/change_password" id="editProfile" onclick="trackWebEngageEvents('My Account Clicked', {'Button Name':'Change password'});" style="display:none">Change password</a>
#  </div>
#  <div class="planSec" id="userPlanSec" style="display:none"></div>
#  <a class="LinkCTA" href="/myreads">My Reads</a>
#  <a class="LinkCTANoArrow" href="https://accounts.hindustantimes.com/logout.html?ref=lm">Logout</a>
#  </div>,
#  <div class="userDetails">
#  <div class="initial" id="userInitials"></div>
#  <div class="uName" id="uName"></div>
#  <a href="https://accounts.hindustantimes.com/lm/change_password" id="editProfile" onclick="trackWebEngageEvents('My Account Clicked', {'Button Name':'Change password'});" style="display:none">Change password</a>
#  </div>,
#  <div class="initial" id="userInitials"></div>,
#  <div class="uName" id="uName"></div>,
#  <div class="planSec" id="userPlanSec" style="display:none"></div>,
#  <div class="Userbgoverlay" id="Userbgoverlay" onclick="closeUserSideProfile()"></div>]

# %%
alldata
# Out:
# []

# %%
mydiv=alldata[2]

# %%
mydiv
# Out:
# <div aria-labelledby="nav-today-tab" class="tab-pane active" id="nav-today" role="tabpanel">
# <div class="main_table_countries_div">
# <table class="table table-bordered table-hover main_table_countries" id="main_table_countries_today" style="width:100%;margin-top: 0px !important;display:none;">
# <thead>
# <tr>
# <th width="1%">#</th>
# <th width="100">Country,<br/>Other</th>
# <th width="20">Total<br/>Cases</th>
# <th width="30">New<br/>Cases</th>
# <th width="30">Total<br/>Deaths</th>
# <th width="30">New<br/>Deaths</th>
# <th width="30">Total<br/>Recovered</th>
# <th width="30">New<br/>Recovered</th>
# <th width="30">Active<br/>Cases</th>
# <th width="30">Serious,<br/>Critical</th>
# <th width="30">Tot Cases/<br/>1M pop</th>
# <th width="30">Deaths/<br/>1M pop</th>
# <th width="30">Total<br/>Tests</th>
# <th width="30">Tests/<br/>
# <nobr>1M pop</nobr>
# </th>
# <th width="30">Population</th>
# <th style="display:none" width="30">Continent</th>
# <th width="30">1 Case<br/>every X ppl</th><th width="30">1 Death<br/>every X ppl</th><th width="30">1 Test<br/>every X ppl</th>
# </tr>
# </thead>
# <tbody>
# <tr class="total_row_world row_continent" data-continent="North America" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>North America</nobr>
# </td>
# <td>3,512,404</td>
# <td>+23,680</td>
# <td>175,747</td>
# <td>+388</td>
# <td>1,573,076</td>
# <td>+6,203</td>
# <td>1,763,581</td>
# <td>19,166</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="North America" style="display:none;">North America</td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="total_row_world row_continent" data-continent="South America" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>South America</nobr>
# </td>
# <td>2,518,385</td>
# <td>+4,251</td>
# <td>93,833</td>
# <td>+148</td>
# <td>1,560,150</td>
# <td>+4,668</td>
# <td>864,402</td>
# <td>13,490</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="South America" style="display:none;">South America</td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="total_row_world row_continent" data-continent="Asia" style="display: none">
# <td></td>
# <td style="text-align:left;">
# <nobr>Asia</nobr>
# </td>
# <td>2,620,708</td>
# <td>+41,256</td>
# <td>63,115</td>
# <td>+952</td>
# <td>1,770,374</td>
# <td>+31,905</td>
# <td>787,219</td>
# <td>19,494</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="Asia" style="display:none;">Asia</td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# <tr class

# <td></td>
# <td><strong>Total:</strong></td>
# <td>3,512,404</td>
# <td style="background-color:#FFEEAA; color:#000;">+23,680</td>
# <td>175,747</td>
# <td style="background-color:red; color:#fff">+388</td>
# <td>1,573,076</td>
# <td style="background-color:#c8e6c9; color:#000">+6,203</td>
# <td>1,763,581</td>
# <td>19,166</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="North America" style="display:none;">North America</td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="row_continent total_row" data-continent="South America" style="display: none">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>2,518,385</td>
# <td style="background-color:#FFEEAA; color:#000;">+4,251</td>
# <td>93,833</td>
# <td style="background-color:red; color:#fff">+148</td>
# <td>1,560,150</td>
# <td style="background-color:#c8e6c9; color:#000">+4,668</td>
# <td>864,402</td>
# <td>13,490</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="South America" style="display:none;">South America</td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="row_continent total_row" data-continent="Asia" style="display: none">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>2,620,708</td>
# <td style="background-color:#FFEEAA; color:#000;">+41,256</td>
# <td>63,115</td>
# <td style="background-color:red; color:#fff">+952</td>
# <td>1,770,374</td>
# <td style="background-color:#c8e6c9; color:#000">+31,905</td>
# <td>787,219</td>
# <td>19,494</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="Asia" style="display:none;">Asia</td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="row_continent total_row" data-continent="Europe" style="display: none">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>2,487,779</td>
# <td style="background-color:#FFEEAA; color:#000;">+10,207</td>
# <td>193,934</td>
# <td style="background-color:red; color:#fff">+237</td>
# <td>1,437,083</td>
# <td style="background-color:#c8e6c9; color:#000">+6,463</td>
# <td>856,762</td>
# <td>5,579</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="Europe" style="display:none;">Europe</td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="row_continent total_row" data-continent="Africa" style="display: none">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>480,705</td>
# <td style="background-color:#FFEEAA; color:#000;">+860</td>
# <td>11,407</td>
# <td style="background-color:red; color:#fff">+7</td>
# <td>230,346</td>
# <td style="background-color:#c8e6c9; color:#000">+330</td>
# <td>238,952</td>
# <td>957</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="Africa" style="display:none;">Africa</td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="row_continent total_row" data-continent="Australia/Oceania" style="display: none">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>10,233</td>
# <td style="background-color:#FFEEAA; color:#000;">+139</td>
# <td>128</td>
# <td style="background-color:red; color:#fff">+2</td>
# <td>9,017</td>
# <td style="background-color:#c8e6c9; color:#000">+21</td>
# <td>1,088</td>
# <td>7</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="Australia/Oceania" style="display:none;">Australia/Oceania</td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# <tr class="row_continent total_row" data-continent="" style="display: none">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>721</td>
# <td style=""></td>
# <td>15</td>
# <td style=""></td>
# <td>651</td>
# <td style=""></td>
# <td>55</td>
# <td>4</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="" style="display:none;"></td>
# <td> </td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# <tbody class="total_row_body body_world">
# <tr class="total_row">
# <td></td>
# <td><strong>Total:</strong></td>
# <td>11,630,935</td>
# <td style="background-color:#FFEEAA; color:#000;">+80,393</td>
# <td>538,179</td>
# <td style="background-color:red; color:#fff">+1,734</td>
# <td>6,580,697</td>
# <td style="background-color:#c8e6c9; color:#000">+49,590</td>
# <td>4,512,059</td>
# <td>58,697</td>
# <td>1,492.1</td>
# <td>69.0</td>
# <td></td>
# <td></td>
# <td></td>
# <td data-continent="all" style="display:none">All</td>
# <td>
# </td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>

# %%
pop=mydiv.find_all("div",attrs={"class":"main_table_countries_div"})

# %%
len(pop)
# Out:
# 1
