# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("data.csv")

# %%
df[:3]
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48

# %%
X=df[["Height"]].values
y=df[["Weight"]].values

# %%
X
# Out:
# array([[1.47],
#        [1.5 ],
#        [1.52],
#        [1.55],
#        [1.57],
#        [1.6 ],
#        [1.63],
#        [1.65],
#        [1.68],
#        [1.7 ],
#        [1.73],
#        [1.75],
#        [1.78],
#        [1.8 ],
#        [1.83]])

# %%
#Spliting up of Dataset into Training and test Dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# # Visualizing TRAIN MODEL

# %%
plt.style.use("seaborn")
plt.scatter(X_train,y_train,c="blue")
plt.plot(X_train,model.predict(X_train), color='red')
plt.title("TRAIN Model")
plt.xlabel('HEIGHT')
plt.ylabel('WEIGHT')
plt.show()

# %% [markdown]
# # Visualizing TEST MODEL

# %%
plt.scatter(X_test,y_test,c="blue")
plt.plot(X_train,model.predict(X_train), color='red')
plt.title("TEST Model")
plt.xlabel('HEIGHT')
plt.ylabel('WEIGHT')
plt.show()

# %%
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_test,y_pred,color='red')
plt.title('Test Set Result')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
plt.scatter(X_test,y_test,c="blue")
plt.plot(X_test,y_pred,color='red')
plt.plot(X_train,model.predict(X_train), color='red')
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error
coefficient_of_dermination = r2_score(y_pred, y_test)
print('R2 Score = ',coefficient_of_dermination)
error=mean_squared_error(y_pred, y_test)
print('Error = ',error)
# Out:
# R2 Score =  0.9861524537037374
# Error =  0.8519463386043973

# %%
df=pd.read_csv("train.csv")

X_train=np.array(df[['x']])
y_train=np.array(df[['y']])

# %%
df.isna().isnull().any()
# Out:
# x    False
# y    False
# dtype: bool

# %%
np.any(np.isnan(df))
# Out:
# True

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %%
df=clean_dataset(df)

# %%
# df=pd.read_csv("test.csv")
# # X_test=df['x'].values
# # y_trst=df['y']

# %%
X_train=np.array(df[['x']])
y_train=np.array(df[['y']])

# %%
# X_train

# %%
plt.scatter(X_train, y_train, color='orange')
plt.xlabel("hardwork")
plt.ylabel("marks")
plt.show()

# %%
mu=X_train.mean()
sigma=X_train.std()
X_train = (X_train - mu)/ sigma

# %%
# import 
from sklearn.linear_model import LinearRegression


# object
model = LinearRegression()
#if u want all your CPU core to work together then you put n_jobs=-1

# %%
# X_train=np.array([X_train])

# %%
# type(X_train)

# %%
# y_train=y_train.ravel()

# %%
y_train
# Out:
# array([[ 21.54945196],
#        [ 47.46446305],
#        [ 17.21865634],
#        [ 36.58639803],
#        [ 87.28898389],
#        [ 32.46387493],
#        [ 10.78089683],
#        [ 80.7633986 ],
#        [ 24.61215147],
#        [  6.96331907],
#        [ 11.23757338],
#        [ 13.53290206],
#        [ 24.60323899],
#        [ 39.40049976],
#        [ 48.43753838],
#        [ 61.69900319],
#        [ 26.92832418],
#        [ 70.4052055 ],
#        [ 29.34092408],
#        [ 25.30895192],
#        [ 69.02934339],
#        [ 84.99484703],
#        [ 57.04310305],
#        [ 50.5921991 ],
#        [ 83.02772202],
#        [ 57.05752706],
#        [ 47.95883341],
#        [ 24.34226432],
#        [ 94.68488281],
#        [ 48.03970696],
#        [  7.08132338],
#        [ 21.99239907],
#        [ 42.33151664],
#        [  0.32908944],
#        [ 61.92303698],
#        [ 91.17716423],
#        [ 39.45358014],
#        [  5.99606961],
#        [ 22.59015942],
#        [ 61.18044414],
# ...

# %%
# training - > fit

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
df1=pd.read_csv("test.csv")
df1=clean_dataset(df1)
X_test =np.array(df1[['x']])

# %%
y_pred = model.predict(X_test)

# %%
y_test=np.array(df1[['y']])

# %%
model.score(X_test,y_test.
# Out:
# -3326.9973918273017

# %%
model.
# Out:
#   File "<ipython-input-251-e5c9403477cf>", line 1
#     model.
#           ^
# SyntaxError: invalid syntax

# %%
X_train.shape
# Out:
# (699, 1)

# %%
y_train.shape
# Out:
# (699, 1)

# %%
plt.scatter(X_train, y_train)
# plt.plot(X_train,(model.intercept_,), color='orange', label="Hypothesis")
#opt theta is theta that is nearer to converge pt
plt.legend("gt")
plt.show()
#basically we ghave predicted  y for training data

# %%
import matplotlib.pyplot as plt
plt.scatter( X_train , y_train )
print(X_train.shape)
plt.plot( X_train, model.predict( X_train.reshape( - 1 , 1 ) ) , 'r')
# Out:
# (699, 1)

# %%
import matplotlib.pyplot as plt
plt.scatter( X_test , y_)
print(X_test.shape)
plt.plot( X_test , model.predict( X_test.reshape( - 1 , 1 ) ) , 'r')
# Out:
# (300, 1)

# %%
# Out:
# array([[ 79.77515201],
#        [ 23.17727887],
#        [ 25.60926156],
#        [ 17.85738813],
#        [ 41.84986439],
#        [  9.80523488],
#        [ 58.87465933],
#        [ 97.61793701],
#        [ 18.39512747],
#        [  8.74674765],
#        [  2.81141583],
#        [ 17.09537241],
#        [ 95.14907176],
#        [ 61.38800663],
#        [ 40.24701716],
#        [ 14.82248589],
#        [ 66.95806869],
#        [ 16.63507984],
#        [ 90.65513736],
#        [ 77.22982636],
#        [ 92.11906278],
#        [ 46.91387709],
#        [ 89.82634442],
#        [ 21.71380347],
#        [ 97.41206981],
#        [ 57.01631363],
#        [ 78.31056542],
#        [ 19.1315097 ],
#        [ 93.03483388],
#        [ 26.59112396],
#        [ 97.55155344],
#        [ 31.43524822],
#        [ 35.12724777],
#        [ 78.61042432],
#        [ 33.07112825],
#        [ 51.69967172],
#        [ 53.62235225],
#        [ 69.46306072],
#        [ 27.42497237],
#        [ 36.34644189],
# ...
