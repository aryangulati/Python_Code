# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### This data set gives average masses for women as a function of their height in a sample of American women of age 30–39.

# %%
df=pd.read_csv("data.csv")

# %% [markdown]
# ### Lets check for Nan Values or not

# %%
np.any(np.isnan(df))
# Out:
# False

# %%
df.isna().isnull().any()
# Out:
# Height    False
# Weight    False
# dtype: bool

# %%
# def clean_dataset(df):
#     assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
#     df.dropna(inplace=True)
#     indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
#     return df[indices_to_keep].astype(np.float64)

# df=clean_dataset(df)

# %%
df[:3]
# Out:
#    Height  Weight
# 0    1.47   52.21
# 1    1.50   53.12
# 2    1.52   54.48

# %%
X=df[["Height"]].values
y=df[["Weight"]].values

# %%
X
# Out:
# array([[1.47],
#        [1.5 ],
#        [1.52],
#        [1.55],
#        [1.57],
#        [1.6 ],
#        [1.63],
#        [1.65],
#        [1.68],
#        [1.7 ],
#        [1.73],
#        [1.75],
#        [1.78],
#        [1.8 ],
#        [1.83]])

# %% [markdown]
# ### Spliting up of Dataset into Training and test Dataset

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X,y,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# # Visualizing TRAIN MODEL

# %%
plt.style.use("seaborn")
plt.scatter(X_train,y_train,c="blue")
plt.plot(X_train,model.predict(X_train), color='red')
plt.title("TRAIN Model")
plt.xlabel('HEIGHT')
plt.ylabel('WEIGHT')
plt.show()

# %% [markdown]
# # Visualizing TEST MODEL

# %%
plt.scatter(X_test,y_test,c="blue")
plt.plot(X_train,model.predict(X_train), color='red')
plt.title("TEST Model")
plt.xlabel('HEIGHT')
plt.ylabel('WEIGHT')
plt.show()

# %%
plt.scatter(X_test,y_test,color='blue')
plt.plot(X_test,y_pred,color='red')
plt.title('Test Set Result')
plt.xlabel('Height')

plt.ylabel('Weight')
plt.show()

# %%
plt.scatter(X_test,y_test,c="blue")
plt.plot(X_test,y_pred,color='red')
plt.plot(X_train,model.predict(X_train), color='red')
plt.show()

# %%
from sklearn.metrics import r2_score,mean_squared_error
coefficient_of_dermination = r2_score(y_pred, y_test)
print('R2 Score = ',coefficient_of_dermination)
error=mean_squared_error(y_pred, y_test)
print('Error = ',error)
# Out:
# R2 Score =  0.9861524537037374
# Error =  0.8519463386043973

# %%
sns.lineplot(x="Height" ,y="Weight"  ,data=df )
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %%
sns.distplot(df["Weight"])
# Out:
# C:\Users\ARYAN GULATI\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(df["Height"])
# Out:
# C:\Users\ARYAN GULATI\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.jointplot(x="Weight",y="Height" ,data =df,kind="scatter")
sns.jointplot(x="Weight",y="Height" ,data =df,kind="hex")
sns.jointplot(x="Weight",y="Height" ,data =df,kind="kde")
sns.jointplot(x="Weight",y="Height" ,data =df,kind="reg")

# %% [markdown]
# ## How to calculate BMI of a person !!

# %%
df['BMI']=df['Weight']/(df['Height']*df['Height'])
df
# Out:
#     Height  Weight        BMI
# 0     1.47   52.21  24.161229
# 1     1.50   53.12  23.608889
# 2     1.52   54.48  23.580332
# 3     1.55   55.84  23.242456
# 4     1.57   57.20  23.205810
# 5     1.60   58.57  22.878906
# 6     1.63   59.93  22.556363
# 7     1.65   61.29  22.512397
# 8     1.68   63.11  22.360402
# 9     1.70   64.47  22.307958
# 10    1.73   66.28  22.145745
# 11    1.75   68.10  22.236735
# 12    1.78   69.92  22.067921
# 13    1.80   72.19  22.280864
# 14    1.83   74.46  22.234166

# %%
sns.distplot(df["BMI"],bins=40)
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %%
sns.heatmap(df,annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x="Height",y="BMI",data=df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='BMI'>

# %%
sns.barplot(x="Weight",y="BMI",data=df)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='BMI'>

# %%
sns.pairplot(df)

# %%
sns.jointplot(x="Weight",y="Height" ,data =df,kind="scatter")
sns.jointplot(x="Weight",y="Height" ,data =df,kind="hex")
sns.jointplot(x="Weight",y="Height" ,data =df,kind="kde")
sns.jointplot(x="Weight",y="Height" ,data =df,kind="reg")
