# %%
from PIL import Image ,ImageDraw,ImageFilter
#see below markdown

# %% [markdown]
# <!--https://note.nkmk.me/en/python-pillow-putalpha/-->

# %%
#Image module of the Python image processing library Pillow (PIL)
#provides putalpha() for adding an alpha channel to an image.

# %%
# Import Image from PIL and load the original image.

# ImageDraw and ImageFilter are used to draw shapes and create alpha channels. 
#They may be omitted if the image file is read and used as an alpha channel.

# %%
img=Image.open("img.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1223x678 at 0x1B61AF67808>

# %%
img2=img.copy()

# %%
# The parameter of putalpha() is only alpha. 
#As it is literally put the alpha channel layer to the original image.
#0 means 100% transparency, 255 means 0% transparency (no transparency).

# %%
# Note that putalpha() overwrites the original image,
#so if you want to keep the original image as it is, 
#use the one copied with copy().

# %%
img2.putalpha(128)

# %%
# alpha=128 gives about 50% transparency (128 / 255 ~ 50%).

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGBA size=1223x678 at 0x1B61AF6A548>

# %%
img2.save("./new_img.png")
