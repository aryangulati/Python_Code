# %%
import cv2
import matplotlib.pyplot as plt

# %%
img  = cv2.imread("bob.jpg")

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
img
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
# ...

# %%
print(img[0,0,0])# => BLue channel
print(img[0,0,1])# => Green channel
print(img[0,0,2])# => Red channel
# Out:
# 254
# 254
# 254

# %%
#cv2 shows bgr
#matplotlib shows rgb

# %%
plt.imshow(img)

# %%
rgb_img=img[:,:,[2,1,0]]
plt.imshow(rgb_img)

# %%
plt.imshow(img[:,:,[0,1,2]])

# %%
rgb_img.shape
# Out:
# (183, 275, 3)

# %%
img.shape
# Out:
# (183, 275, 3)
